# %% [markdown]
# # Data Collection and Acquisation

# %%
# !pip install split-folders
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl.metadata (6.2 kB)
# Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
import splitfolders

# Path to your dataset
input_folder = '/kaggle/input/alzheimers-synthesized-dataset/dataset/normal_dataset'

# Output folder
output_folder = './Dataset'

# Split the dataset (train: 80%, val: 10%, test: 10%)
splitfolders.ratio(input_folder, output=output_folder, seed=1337, ratio=(.8, .1, .1))
# Out:
# Copying files: 8000 files [04:11, 31.85 files/s]

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
import seaborn as sns
from tensorflow import keras
from sklearn.metrics import confusion_matrix
from keras.layers import Input,Lambda,Dense,Flatten,BatchNormalization,Dropout
from keras import Model
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard
import datetime
# Out:
# 2024-07-14 15:44:41.525529: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-14 15:44:41.525629: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-14 15:44:41.676352: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
#re-sizing all images to this size
IMAGE_SIZE = [128,128]

#training config
epochs = 200
batch_size = 32

# %%
train_path = './Dataset/train'
val_path = './Dataset/val'
test_path = './Dataset/test'

# useful for getting the number of files
image_files = glob(train_path + '/*/*.jp*g')
val_image_files = glob(val_path + '/*/*.jp*g')
test_image_files = glob(test_path + '/*/*.jp*g')

# useful for getting number of classes
folders = glob(train_path + '/*')
num_classes = len(folders)

# %%
train_gen = ImageDataGenerator(
    rescale=1./255,
#     rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)


val_gen = ImageDataGenerator(
 rescale=1./255,
)

test_gen = ImageDataGenerator(
     rescale=1./255,
)

#create generator

train_generator = train_gen.flow_from_directory(
    train_path,
    target_size = IMAGE_SIZE,
    shuffle = True,
    batch_size = batch_size
)

val_generator = val_gen.flow_from_directory(
    val_path,
    target_size = IMAGE_SIZE,
    shuffle = True,
    batch_size = batch_size
)

test_generator = test_gen.flow_from_directory(
    test_path,
    target_size = IMAGE_SIZE,
    shuffle = True,
    batch_size = batch_size
)
# Out:
# Found 6400 images belonging to 4 classes.
# Found 800 images belonging to 4 classes.
# Found 800 images belonging to 4 classes.

# %% [markdown]
# # Modelling

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16, ResNet50, Xception, InceptionV3, MobileNetV2, DenseNet121
from tensorflow.keras.applications.efficientnet import EfficientNetB0
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model

class ModelZoo:
    def __init__(self):
        self.models = {
            'VGG16': VGG16,
            'ResNet50': ResNet50,
            'Xception': Xception,
            'InceptionV3': InceptionV3,
            'MobileNetV2': MobileNetV2,
            'DenseNet121': DenseNet121,
            'EfficientNetB0': EfficientNetB0
        }

    def load_model(self, model_name):
        if model_name not in self.models:
            raise ValueError(f"Model {model_name} not found in model zoo. Available models: {list(self.models.keys())}")
        return self.models[model_name](input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

def create_custom_model(model_name, num_layers_to_train, num_classes, num_dense_units=(64, 16), dropout_rate=0.2, optimizer='adam'):
    """
    Create a custom model based on the specified base model and other parameters.
    """
    model_zoo = ModelZoo()
    base_model = model_zoo.load_model(model_name)

    # Freeze layers
    for layer in base_model.layers:
        layer.trainable = False

    # Set the last num_layers_to_train layers to be trainable
    for layer in base_model.layers[-num_layers_to_train:]:
        layer.trainable = True

    # Flatten the output of the base model
    x = Flatten()(base_model.output)

    # Add dense layers
    for units in num_dense_units:
        x = Dense(units, activation='relu', kernel_initializer='he_uniform')(x)
        x = BatchNormalization()(x)
        x = Dropout(dropout_rate)(x)

    # Final prediction layer
    prediction = Dense(num_classes, activation='softmax', kernel_initializer='glorot_uniform')(x)

    # Create the final model
    custom_model = Model(inputs=base_model.input, outputs=prediction)

    custom_model.compile(
        loss='categorical_crossentropy',
        optimizer=optimizer,
        metrics=['accuracy']
    )

    return custom_model

# %%
            # 'VGG16': VGG16,
            # 'ResNet50': ResNet50,
            # 'Xception': Xception,
            # 'InceptionV3': InceptionV3,
            # 'MobileNetV2': MobileNetV2,
            # 'DenseNet121': DenseNet121,
            # 'EfficientNetB0': EfficientNetB0

model_name = 'InceptionV3'
selected_model_name = model_name
num_layers_to_train = 0

model = create_custom_model(model_name, num_layers_to_train, num_classes=num_classes)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 63, 63,    │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 63, 63,    │         96 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 63, 63,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 61, 61,    │      9,216 │ activation[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 61, 61,    │         96 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 61, 61,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 61, 61,    │     18,432 │ activation_1[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 61, 61,    │        192 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 61, 61,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 30, 30,    │          0 │ activation_2[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 30, 30,    │      5,120 │ max_pooling2d[0]… │
# │                     │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 30, 30,    │        240 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 30, 30,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 28, 28,    │    138,240 │ activation_3[0][… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        576 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 13, 13,    │          0 │ activation_4[0][… │
# │ (MaxPooling2D)      │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 13, 13,    │     12,288 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │        192 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 13, 13,    │      9,216 │ max_pooling2d_1[… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 13, 13,    │     55,296 │ activation_8[0][… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │        144 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │        288 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d   │ (None, 13, 13,    │          0 │ max_pooling2d_1[… │
# │ (AveragePooling2D)  │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 13, 13,    │     12,288 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 13, 13,    │     76,800 │ activation_6[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 13, 13,    │     82,944 │ activation_9[0][… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 13, 13,    │      6,144 │ average_pooling2… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │        192 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │        192 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │        288 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │         96 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed0              │ (None, 13, 13,    │          0 │ activation_5[0][… │
# │ (Concatenate)       │ 256)              │            │ activation_7[0][… │
# │                     │                   │            │ activation_10[0]… │
# │                     │                   │            │ activation_11[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 13, 13,    │     16,384 │ mixed0[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │        192 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 13, 13,    │     12,288 │ mixed0[0][0]      │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 13, 13,    │     55,296 │ activation_15[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │        144 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │        288 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_1 │ (None, 13, 13,    │          0 │ mixed0[0][0]      │
# │ (AveragePooling2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 13, 13,    │     16,384 │ mixed0[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 13, 13,    │     76,800 │ activation_13[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 13, 13,    │     82,944 │ activation_16[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 13, 13,    │     16,384 │ average_pooling2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │        192 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │        192 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │        288 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │        192 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed1              │ (None, 13, 13,    │          0 │ activation_12[0]… │
# │ (Concatenate)       │ 288)              │            │ activation_14[0]… │
# │                     │                   │            │ activation_17[0]… │
# │                     │                   │            │ activation_18[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 13, 13,    │     18,432 │ mixed1[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │        192 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 13, 13,    │     13,824 │ mixed1[0][0]      │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 13, 13,    │     55,296 │ activation_22[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │        144 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │        288 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_2 │ (None, 13, 13,    │          0 │ mixed1[0][0]      │
# │ (AveragePooling2D)  │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 13, 13,    │     18,432 │ mixed1[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 13, 13,    │     76,800 │ activation_20[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 13, 13,    │     82,944 │ activation_23[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 13, 13,    │     18,432 │ average_pooling2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │        192 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │        192 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │        288 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │        192 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed2              │ (None, 13, 13,    │          0 │ activation_19[0]… │
# │ (Concatenate)       │ 288)              │            │ activation_21[0]… │
# │                     │                   │            │ activation_24[0]… │
# │                     │                   │            │ activation_25[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 13, 13,    │     18,432 │ mixed2[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │        192 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 13, 13,    │     55,296 │ activation_27[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │        288 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 6, 6, 384) │    995,328 │ mixed2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 6, 6, 96)  │     82,944 │ activation_28[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 384) │      1,152 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 96)  │        288 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 6, 6, 384) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, 6, 6, 96)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 6, 6, 288) │          0 │ mixed2[0][0]      │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed3              │ (None, 6, 6, 768) │          0 │ activation_26[0]… │
# │ (Concatenate)       │                   │            │ activation_29[0]… │
# │                     │                   │            │ max_pooling2d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 6, 6, 128) │     98,304 │ mixed3[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 128) │        384 │ conv2d_34[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_34       │ (None, 6, 6, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 6, 6, 128) │    114,688 │ activation_34[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 128) │        384 │ conv2d_35[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_35       │ (None, 6, 6, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 6, 6, 128) │     98,304 │ mixed3[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 6, 6, 128) │    114,688 │ activation_35[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 128) │        384 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 128) │        384 │ conv2d_36[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_31       │ (None, 6, 6, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_36       │ (None, 6, 6, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 6, 6, 128) │    114,688 │ activation_31[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 6, 6, 128) │    114,688 │ activation_36[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 128) │        384 │ conv2d_32[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 128) │        384 │ conv2d_37[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_32       │ (None, 6, 6, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_37       │ (None, 6, 6, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_3 │ (None, 6, 6, 768) │          0 │ mixed3[0][0]      │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 6, 6, 192) │    147,456 │ mixed3[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 6, 6, 192) │    172,032 │ activation_32[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 6, 6, 192) │    172,032 │ activation_37[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 6, 6, 192) │    147,456 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 192) │        576 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 192) │        576 │ conv2d_33[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 192) │        576 │ conv2d_38[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 192) │        576 │ conv2d_39[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_30       │ (None, 6, 6, 192) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_33       │ (None, 6, 6, 192) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_38       │ (None, 6, 6, 192) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_39       │ (None, 6, 6, 192) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed4              │ (None, 6, 6, 768) │          0 │ activation_30[0]… │
# │ (Concatenate)       │                   │            │ activation_33[0]… │
# │                     │                   │            │ activation_38[0]… │
# │                     │                   │            │ activation_39[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 6, 6, 160) │    122,880 │ mixed4[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 160) │        480 │ conv2d_44[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_44       │ (None, 6, 6, 160) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 6, 6, 160) │    179,200 │ activation_44[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 160) │        480 │ conv2d_45[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_45       │ (None, 6, 6, 160) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 6, 6, 160) │    122,880 │ mixed4[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (None, 6, 6, 160) │    179,200 │ activation_45[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 160) │        480 │ conv2d_41[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 160) │        480 │ conv2d_46[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_41       │ (None, 6, 6, 160) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_46       │ (None, 6, 6, 160) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 6, 6, 160) │    179,200 │ activation_41[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_47 (Conv2D)  │ (None, 6, 6, 160) │    179,200 │ activation_46[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 160) │        480 │ conv2d_42[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 160) │        480 │ conv2d_47[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_42       │ (None, 6, 6, 160) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_47       │ (None, 6, 6, 160) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_4 │ (None, 6, 6, 768) │          0 │ mixed4[0][0]      │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 6, 6, 192) │    147,456 │ mixed4[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 6, 6, 192) │    215,040 │ activation_42[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_48 (Conv2D)  │ (None, 6, 6, 192) │    215,040 │ activation_47[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (None, 6, 6, 192) │    147,456 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 192) │        576 │ conv2d_40[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 192) │        576 │ conv2d_43[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 192) │        576 │ conv2d_48[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 192) │        576 │ conv2d_49[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_40       │ (None, 6, 6, 192) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_43       │ (None, 6, 6, 192) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_48       │ (None, 6, 6, 192) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_49       │ (None, 6, 6, 192) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed5              │ (None, 6, 6, 768) │          0 │ activation_40[0]… │
# │ (Concatenate)       │                   │            │ activation_43[0]… │
# │                     │                   │            │ activation_48[0]… │
# │                     │                   │            │ activation_49[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_54 (Conv2D)  │ (None, 6, 6, 160) │    122,880 │ mixed5[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 160) │        480 │ conv2d_54[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_54       │ (None, 6, 6, 160) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_55 (Conv2D)  │ (None, 6, 6, 160) │    179,200 │ activation_54[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 160) │        480 │ conv2d_55[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_55       │ (None, 6, 6, 160) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_51 (Conv2D)  │ (None, 6, 6, 160) │    122,880 │ mixed5[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_56 (Conv2D)  │ (None, 6, 6, 160) │    179,200 │ activation_55[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 160) │        480 │ conv2d_51[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 160) │        480 │ conv2d_56[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_51       │ (None, 6, 6, 160) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_56       │ (None, 6, 6, 160) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_52 (Conv2D)  │ (None, 6, 6, 160) │    179,200 │ activation_51[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_57 (Conv2D)  │ (None, 6, 6, 160) │    179,200 │ activation_56[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 160) │        480 │ conv2d_52[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 160) │        480 │ conv2d_57[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_52       │ (None, 6, 6, 160) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_57       │ (None, 6, 6, 160) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_5 │ (None, 6, 6, 768) │          0 │ mixed5[0][0]      │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_50 (Conv2D)  │ (None, 6, 6, 192) │    147,456 │ mixed5[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_53 (Conv2D)  │ (None, 6, 6, 192) │    215,040 │ activation_52[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_58 (Conv2D)  │ (None, 6, 6, 192) │    215,040 │ activation_57[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_59 (Conv2D)  │ (None, 6, 6, 192) │    147,456 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 192) │        576 │ conv2d_50[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 192) │        576 │ conv2d_53[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 192) │        576 │ conv2d_58[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 192) │        576 │ conv2d_59[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_50       │ (None, 6, 6, 192) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_53       │ (None, 6, 6, 192) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_58       │ (None, 6, 6, 192) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_59       │ (None, 6, 6, 192) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed6              │ (None, 6, 6, 768) │          0 │ activation_50[0]… │
# │ (Concatenate)       │                   │            │ activation_53[0]… │
# │                     │                   │            │ activation_58[0]… │
# │                     │                   │            │ activation_59[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_64 (Conv2D)  │ (None, 6, 6, 192) │    147,456 │ mixed6[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 192) │        576 │ conv2d_64[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_64       │ (None, 6, 6, 192) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_65 (Conv2D)  │ (None, 6, 6, 192) │    258,048 │ activation_64[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 192) │        576 │ conv2d_65[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_65       │ (None, 6, 6, 192) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_61 (Conv2D)  │ (None, 6, 6, 192) │    147,456 │ mixed6[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_66 (Conv2D)  │ (None, 6, 6, 192) │    258,048 │ activation_65[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 192) │        576 │ conv2d_61[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 192) │        576 │ conv2d_66[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_61       │ (None, 6, 6, 192) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_66       │ (None, 6, 6, 192) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_62 (Conv2D)  │ (None, 6, 6, 192) │    258,048 │ activation_61[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_67 (Conv2D)  │ (None, 6, 6, 192) │    258,048 │ activation_66[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 192) │        576 │ conv2d_62[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 192) │        576 │ conv2d_67[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_62       │ (None, 6, 6, 192) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...
# │ batch_normalizatio… │ (None, 2, 2, 192) │        576 │ conv2d_75[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_71       │ (None, 2, 2, 320) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_75       │ (None, 2, 2, 192) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 2, 2, 768) │          0 │ mixed7[0][0]      │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed8              │ (None, 2, 2,      │          0 │ activation_71[0]… │
# │ (Concatenate)       │ 1280)             │            │ activation_75[0]… │
# │                     │                   │            │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_80 (Conv2D)  │ (None, 2, 2, 448) │    573,440 │ mixed8[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 448) │      1,344 │ conv2d_80[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_80       │ (None, 2, 2, 448) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_77 (Conv2D)  │ (None, 2, 2, 384) │    491,520 │ mixed8[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_81 (Conv2D)  │ (None, 2, 2, 384) │  1,548,288 │ activation_80[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 384) │      1,152 │ conv2d_77[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 384) │      1,152 │ conv2d_81[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_77       │ (None, 2, 2, 384) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_81       │ (None, 2, 2, 384) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_78 (Conv2D)  │ (None, 2, 2, 384) │    442,368 │ activation_77[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_79 (Conv2D)  │ (None, 2, 2, 384) │    442,368 │ activation_77[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_82 (Conv2D)  │ (None, 2, 2, 384) │    442,368 │ activation_81[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_83 (Conv2D)  │ (None, 2, 2, 384) │    442,368 │ activation_81[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_7 │ (None, 2, 2,      │          0 │ mixed8[0][0]      │
# │ (AveragePooling2D)  │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_76 (Conv2D)  │ (None, 2, 2, 320) │    409,600 │ mixed8[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 384) │      1,152 │ conv2d_78[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 384) │      1,152 │ conv2d_79[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 384) │      1,152 │ conv2d_82[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 384) │      1,152 │ conv2d_83[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_84 (Conv2D)  │ (None, 2, 2, 192) │    245,760 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 320) │        960 │ conv2d_76[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_78       │ (None, 2, 2, 384) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_79       │ (None, 2, 2, 384) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_82       │ (None, 2, 2, 384) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_83       │ (None, 2, 2, 384) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 192) │        576 │ conv2d_84[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_76       │ (None, 2, 2, 320) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed9_0            │ (None, 2, 2, 768) │          0 │ activation_78[0]… │
# │ (Concatenate)       │                   │            │ activation_79[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 2, 2, 768) │          0 │ activation_82[0]… │
# │ (Concatenate)       │                   │            │ activation_83[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_84       │ (None, 2, 2, 192) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed9              │ (None, 2, 2,      │          0 │ activation_76[0]… │
# │ (Concatenate)       │ 2048)             │            │ mixed9_0[0][0],   │
# │                     │                   │            │ concatenate[0][0… │
# │                     │                   │            │ activation_84[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_89 (Conv2D)  │ (None, 2, 2, 448) │    917,504 │ mixed9[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 448) │      1,344 │ conv2d_89[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_89       │ (None, 2, 2, 448) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_86 (Conv2D)  │ (None, 2, 2, 384) │    786,432 │ mixed9[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_90 (Conv2D)  │ (None, 2, 2, 384) │  1,548,288 │ activation_89[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 384) │      1,152 │ conv2d_86[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 384) │      1,152 │ conv2d_90[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_86       │ (None, 2, 2, 384) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_90       │ (None, 2, 2, 384) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_87 (Conv2D)  │ (None, 2, 2, 384) │    442,368 │ activation_86[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_88 (Conv2D)  │ (None, 2, 2, 384) │    442,368 │ activation_86[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_91 (Conv2D)  │ (None, 2, 2, 384) │    442,368 │ activation_90[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_92 (Conv2D)  │ (None, 2, 2, 384) │    442,368 │ activation_90[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_8 │ (None, 2, 2,      │          0 │ mixed9[0][0]      │
# │ (AveragePooling2D)  │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_85 (Conv2D)  │ (None, 2, 2, 320) │    655,360 │ mixed9[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 384) │      1,152 │ conv2d_87[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 384) │      1,152 │ conv2d_88[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 384) │      1,152 │ conv2d_91[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 384) │      1,152 │ conv2d_92[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_93 (Conv2D)  │ (None, 2, 2, 192) │    393,216 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 320) │        960 │ conv2d_85[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_87       │ (None, 2, 2, 384) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_88       │ (None, 2, 2, 384) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_91       │ (None, 2, 2, 384) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_92       │ (None, 2, 2, 384) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 192) │        576 │ conv2d_93[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_85       │ (None, 2, 2, 320) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed9_1            │ (None, 2, 2, 768) │          0 │ activation_87[0]… │
# │ (Concatenate)       │                   │            │ activation_88[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 2, 2, 768) │          0 │ activation_91[0]… │
# │ (Concatenate)       │                   │            │ activation_92[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_93       │ (None, 2, 2, 192) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed10             │ (None, 2, 2,      │          0 │ activation_85[0]… │
# │ (Concatenate)       │ 2048)             │            │ mixed9_1[0][0],   │
# │                     │                   │            │ concatenate_1[0]… │
# │                     │                   │            │ activation_93[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 8192)      │          0 │ mixed10[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │    524,352 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 16)        │      1,040 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16)        │         64 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 16)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 4)         │         68 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 22,328,564 (85.18 MB)
#  Trainable params: 22,293,972 (85.04 MB)
#  Non-trainable params: 34,592 (135.12 KB)

# %%
from tensorflow.keras.utils import plot_model

# Visualize the model architecture
plot_model(model,
#            show_shapes=True,
#            show_layer_names=True,
           to_file='model.png')

# %% [markdown]
# # Training

# %%
import tensorflow as tf
from keras.callbacks import (
    EarlyStopping,
    ModelCheckpoint,
#     TensorBoard,
    ReduceLROnPlateau,
    CSVLogger,
    LearningRateScheduler,
    Callback
)
import datetime

# Define early stopping
early_stopping = EarlyStopping(monitor="val_loss", patience=10)

# Define model checkpointing
model_checkpoint = ModelCheckpoint(
    "best_model.keras", monitor="val_loss", save_best_only=True
)

# Define TensorBoard callback
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(
    log_dir=log_dir, histogram_freq=1, update_freq="epoch"
)

# Define ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.2, patience=5, min_lr=1e-6)

# Define CSVLogger callback
csv_logger = tf.keras.callbacks.CSVLogger("training.log")


# Define LearningRateScheduler callback
def lr_scheduler(epoch, lr):
    if epoch % 10 == 0:
        return lr * 0.9
    else:
        return lr


lr_scheduler_callback = LearningRateScheduler(lr_scheduler)

class EpochLogger(Callback):
    def on_epoch_begin(self, epoch, logs=None):
        print(f"Starting epoch {epoch + 1}")
        self.current_epoch = epoch + 1

epoch_logger = EpochLogger()

# Combine all callbacks
callbacks = [
    early_stopping,
    model_checkpoint,
#     tensorboard_callback,
    reduce_lr,
    csv_logger,
    lr_scheduler_callback,
    epoch_logger
]

# %%
import time
import pandas as pd
from keras.optimizers import Adam, RMSprop, SGD, Adagrad, Adadelta, Nadam, AdamW

def define_optimizers():
    return {
        "Adam": Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-7, amsgrad=False),
#         "SGD": SGD(learning_rate=0.001, momentum=0.009, nesterov=False),
#         "Adagrad": Adagrad(learning_rate=0.001, epsilon=1e-7),
#         "Adadelta": Adadelta(learning_rate=0.001, rho=0.95, epsilon=1e-7),
#         "Nadam": Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-7),
#         "RMSprop": RMSprop(learning_rate=0.001, rho=0.9, momentum=0.0, epsilon=1e-7),
#         "AdamW": AdamW(learning_rate=1e-3, beta_1=0.9, beta_2=0.999, epsilon=1e-7, weight_decay=1e-2)
    }

def train_and_evaluate(model, train_generator, val_generator, test_generator, callbacks, batch_size):
    start_time = time.time()
    history = model.fit(
        train_generator,
        validation_data=val_generator,
        epochs=epochs,
        callbacks=callbacks,
        batch_size=batch_size,
        verbose=1,
    )
    training_time = (time.time() - start_time) / 60.0
    test_loss, test_accuracy = model.evaluate(test_generator, verbose=0)
    return history, training_time, test_loss, test_accuracy

def collect_metrics(history, training_time, test_loss, test_accuracy, model_name):
    return {
        'Model Name': model_name,
        'epoch': range(1, len(history.history['loss']) + 1),
        'train_loss': history.history['loss'],
        'train_accuracy': history.history['accuracy'],
        'val_loss': history.history['val_loss'],
        'val_accuracy': history.history['val_accuracy'],
        'training_time_minutes': [training_time] * len(history.history['loss']),
        'test_loss': [test_loss] * len(history.history['loss']),
        'test_accuracy': [test_accuracy] * len(history.history['loss'])
    }

def save_metrics(metrics, filename):
    pd.DataFrame(metrics).to_csv(filename, index=False)
    print(f"Metrics saved to {filename}")

def calculate_mean_metrics(metrics):
    return {
        'Model Name': metrics['Model Name'],
        'Optimizer': metrics['Optimizer'],
        'Mean_Train_Loss': np.mean(metrics['train_loss']),
        'Mean_Train_Accuracy': np.mean(metrics['train_accuracy']),
        'Mean_Val_Loss': np.mean(metrics['val_loss']),
        'Mean_Val_Accuracy': np.mean(metrics['val_accuracy']),
        'Total_Training_Time_Minutes': np.sum(metrics['training_time_minutes']),
        'Test_Loss': metrics['test_loss'][0],
        'Test_Accuracy': metrics['test_accuracy'][0]
    }

# %%
optimizers = define_optimizers()
summary_results = []
best_optimizer = None
best_val_accuracy = 0.0

for name, optimizer in optimizers.items():
    model = create_custom_model(model_name, num_layers_to_train, num_classes ,optimizer=optimizer)
    history, training_time, test_loss, test_accuracy = train_and_evaluate(
        model, train_generator, val_generator, test_generator, callbacks, batch_size=256
    )

    metrics = collect_metrics(history, training_time, test_loss, test_accuracy, model_name)
    metrics['Optimizer'] = name
    
    save_metrics(metrics, f"{name}_metrics_{model_name}.csv")
    
    mean_metrics = calculate_mean_metrics(metrics)
    summary_results.append(mean_metrics)

    if test_accuracy > best_val_accuracy:
        best_val_accuracy = test_accuracy
        best_optimizer = name

summary_df = pd.DataFrame(summary_results)
save_metrics(summary_df, f"summary_metrics_{model_name}.csv")

if best_optimizer:
    best_metrics_df = pd.read_csv(f"{best_optimizer}_metrics_{model_name}.csv")
    save_metrics(best_metrics_df, f"best_optimizer_metrics_{best_optimizer}_{model_name}.csv")
# Out:
# Starting epoch 1
# Epoch 1/200
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1720971998.883151     100 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1720971998.994068     100 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.3329 - loss: 1.5647
# W0000 00:00:1720972031.645131     100 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 124s 176ms/step - accuracy: 0.3333 - loss: 1.5634 - val_accuracy: 0.5300 - val_loss: 1.6017 - learning_rate: 9.0000e-04
# Starting epoch 2
# Epoch 2/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 30s 145ms/step - accuracy: 0.6038 - loss: 0.8729 - val_accuracy: 0.6650 - val_loss: 0.7256 - learning_rate: 9.0000e-04
# Starting epoch 3
# Epoch 3/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 137ms/step - accuracy: 0.6660 - loss: 0.7411 - val_accuracy: 0.4175 - val_loss: 1.6835 - learning_rate: 9.0000e-04
# Starting epoch 4
# Epoch 4/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 137ms/step - accuracy: 0.6930 - loss: 0.6748 - val_accuracy: 0.5263 - val_loss: 1.1014 - learning_rate: 9.0000e-04
# Starting epoch 5
# Epoch 5/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 30s 144ms/step - accuracy: 0.7370 - loss: 0.6061 - val_accuracy: 0.6925 - val_loss: 0.6551 - learning_rate: 9.0000e-04
# Starting epoch 6
# Epoch 6/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 136ms/step - accuracy: 0.7701 - loss: 0.5436 - val_accuracy: 0.6225 - val_loss: 0.7170 - learning_rate: 9.0000e-04
# Starting epoch 7
# Epoch 7/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 30s 144ms/step - accuracy: 0.7760 - loss: 0.5252 - val_accuracy: 0.7763 - val_loss: 0.5015 - learning_rate: 9.0000e-04
# Starting epoch 8
# Epoch 8/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 135ms/step - accuracy: 0.8010 - loss: 0.4732 - val_accuracy: 0.7163 - val_loss: 0.7198 - learning_rate: 9.0000e-04
# Starting epoch 9
# Epoch 9/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 136ms/step - accuracy: 0.8265 - loss: 0.4477 - val_accuracy: 0.6575 - val_loss: 0.9393 - learning_rate: 9.0000e-04
# Starting epoch 10
# Epoch 10/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 30s 143ms/step - accuracy: 0.8362 - loss: 0.4037 - val_accuracy: 0.8163 - val_loss: 0.4550 - learning_rate: 9.0000e-04
# Starting epoch 11
# Epoch 11/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 135ms/step - accuracy: 0.8588 - loss: 0.3502 - val_accuracy: 0.5512 - val_loss: 1.6848 - learning_rate: 8.1000e-04
# Starting epoch 12
# Epoch 12/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 138ms/step - accuracy: 0.8760 - loss: 0.3225 - val_accuracy: 0.5788 - val_loss: 1.5813 - learning_rate: 8.1000e-04
# Starting epoch 13
# Epoch 13/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 137ms/step - accuracy: 0.8875 - loss: 0.2964 - val_accuracy: 0.7837 - val_loss: 0.6078 - learning_rate: 8.1000e-04
# Starting epoch 14
# Epoch 14/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 136ms/step - accuracy: 0.8975 - loss: 0.2899 - val_accuracy: 0.8062 - val_loss: 0.5515 - learning_rate: 8.1000e-04
# Starting epoch 15
# Epoch 15/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 136ms/step - accuracy: 0.9023 - loss: 0.2732 - val_accuracy: 0.6263 - val_loss: 0.9927 - learning_rate: 1.6200e-04
# Starting epoch 16
# Epoch 16/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 30s 145ms/step - accuracy: 0.9328 - loss: 0.1917 - val_accuracy: 0.9200 - val_loss: 0.2074 - learning_rate: 1.6200e-04
# Starting epoch 17
# Epoch 17/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 30s 143ms/step - accuracy: 0.9638 - loss: 0.1172 - val_accuracy: 0.9250 - val_loss: 0.1976 - learning_rate: 1.6200e-04
# Starting epoch 18
# Epoch 18/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 41s 143ms/step - accuracy: 0.9732 - loss: 0.0920 - val_accuracy: 0.9350 - val_loss: 0.1874 - learning_rate: 1.6200e-04
# Starting epoch 19
# Epoch 19/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 135ms/step - accuracy: 0.9758 - loss: 0.0853 - val_accuracy: 0.9187 - val_loss: 0.2222 - learning_rate: 1.6200e-04
# Starting epoch 20
# Epoch 20/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 136ms/step - accuracy: 0.9831 - loss: 0.0721 - val_accuracy: 0.9325 - val_loss: 0.1940 - learning_rate: 1.6200e-04
# Starting epoch 21
# Epoch 21/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 30s 144ms/step - accuracy: 0.9775 - loss: 0.0751 - val_accuracy: 0.9538 - val_loss: 0.1376 - learning_rate: 1.4580e-04
# Starting epoch 22
# Epoch 22/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 135ms/step - accuracy: 0.9887 - loss: 0.0499 - val_accuracy: 0.9438 - val_loss: 0.1772 - learning_rate: 1.4580e-04
# Starting epoch 23
# Epoch 23/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 139ms/step - accuracy: 0.9842 - loss: 0.0664 - val_accuracy: 0.9225 - val_loss: 0.2173 - learning_rate: 1.4580e-04
# Starting epoch 24
# Epoch 24/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 137ms/step - accuracy: 0.9865 - loss: 0.0488 - val_accuracy: 0.9400 - val_loss: 0.1777 - learning_rate: 1.4580e-04
# Starting epoch 25
# Epoch 25/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 136ms/step - accuracy: 0.9825 - loss: 0.0580 - val_accuracy: 0.9000 - val_loss: 0.2934 - learning_rate: 1.4580e-04
# Starting epoch 26
# Epoch 26/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 140ms/step - accuracy: 0.9866 - loss: 0.0482 - val_accuracy: 0.9488 - val_loss: 0.1460 - learning_rate: 2.9160e-05
# Starting epoch 27
# Epoch 27/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 30s 147ms/step - accuracy: 0.9912 - loss: 0.0363 - val_accuracy: 0.9575 - val_loss: 0.1276 - learning_rate: 2.9160e-05
# Starting epoch 28
# Epoch 28/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 31s 149ms/step - accuracy: 0.9940 - loss: 0.0296 - val_accuracy: 0.9538 - val_loss: 0.1209 - learning_rate: 2.9160e-05
# Starting epoch 29
# Epoch 29/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 140ms/step - accuracy: 0.9928 - loss: 0.0290 - val_accuracy: 0.9575 - val_loss: 0.1217 - learning_rate: 2.9160e-05
# Starting epoch 30
# Epoch 30/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 140ms/step - accuracy: 0.9939 - loss: 0.0266 - val_accuracy: 0.9588 - val_loss: 0.1238 - learning_rate: 2.9160e-05
# Starting epoch 31
# Epoch 31/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 30s 147ms/step - accuracy: 0.9974 - loss: 0.0193 - val_accuracy: 0.9575 - val_loss: 0.1187 - learning_rate: 2.6244e-05
# Starting epoch 32
# Epoch 32/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 30s 146ms/step - accuracy: 0.9962 - loss: 0.0208 - val_accuracy: 0.9625 - val_loss: 0.1158 - learning_rate: 2.6244e-05
# Starting epoch 33
# Epoch 33/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 138ms/step - accuracy: 0.9963 - loss: 0.0196 - val_accuracy: 0.9625 - val_loss: 0.1172 - learning_rate: 2.6244e-05
# Starting epoch 34
# Epoch 34/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 139ms/step - accuracy: 0.9967 - loss: 0.0185 - val_accuracy: 0.9575 - val_loss: 0.1222 - learning_rate: 2.6244e-05
# Starting epoch 35
# Epoch 35/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 138ms/step - accuracy: 0.9935 - loss: 0.0302 - val_accuracy: 0.9563 - val_loss: 0.1243 - learning_rate: 2.6244e-05
# Starting epoch 36
# Epoch 36/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 139ms/step - accuracy: 0.9965 - loss: 0.0189 - val_accuracy: 0.9588 - val_loss: 0.1234 - learning_rate: 2.6244e-05
# Starting epoch 37
# Epoch 37/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 138ms/step - accuracy: 0.9954 - loss: 0.0227 - val_accuracy: 0.9600 - val_loss: 0.1240 - learning_rate: 5.2488e-06
# Starting epoch 38
# Epoch 38/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 140ms/step - accuracy: 0.9956 - loss: 0.0189 - val_accuracy: 0.9625 - val_loss: 0.1181 - learning_rate: 5.2488e-06
# Starting epoch 39
# Epoch 39/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 30s 146ms/step - accuracy: 0.9989 - loss: 0.0115 - val_accuracy: 0.9600 - val_loss: 0.1114 - learning_rate: 5.2488e-06
# Starting epoch 40
# Epoch 40/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 30s 146ms/step - accuracy: 0.9977 - loss: 0.0140 - val_accuracy: 0.9613 - val_loss: 0.1089 - learning_rate: 5.2488e-06
# Starting epoch 41
# Epoch 41/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 30s 144ms/step - accuracy: 0.9975 - loss: 0.0134 - val_accuracy: 0.9613 - val_loss: 0.1052 - learning_rate: 4.7239e-06
# Starting epoch 42
# Epoch 42/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 137ms/step - accuracy: 0.9976 - loss: 0.0185 - val_accuracy: 0.9588 - val_loss: 0.1074 - learning_rate: 4.7239e-06
# Starting epoch 43
# Epoch 43/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 137ms/step - accuracy: 0.9970 - loss: 0.0175 - val_accuracy: 0.9588 - val_loss: 0.1084 - learning_rate: 4.7239e-06
# Starting epoch 44
# Epoch 44/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 139ms/step - accuracy: 0.9986 - loss: 0.0143 - val_accuracy: 0.9600 - val_loss: 0.1069 - learning_rate: 4.7239e-06
# Starting epoch 45
# Epoch 45/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 30s 146ms/step - accuracy: 0.9959 - loss: 0.0159 - val_accuracy: 0.9613 - val_loss: 0.1042 - learning_rate: 4.7239e-06
# Starting epoch 46
# Epoch 46/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 30s 145ms/step - accuracy: 0.9985 - loss: 0.0132 - val_accuracy: 0.9638 - val_loss: 0.1027 - learning_rate: 4.7239e-06
# Starting epoch 47
# Epoch 47/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 30s 144ms/step - accuracy: 0.9983 - loss: 0.0131 - val_accuracy: 0.9638 - val_loss: 0.1021 - learning_rate: 4.7239e-06
# Starting epoch 48
# Epoch 48/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 136ms/step - accuracy: 0.9972 - loss: 0.0157 - val_accuracy: 0.9650 - val_loss: 0.1026 - learning_rate: 4.7239e-06
# Starting epoch 49
# Epoch 49/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 138ms/step - accuracy: 0.9994 - loss: 0.0102 - val_accuracy: 0.9613 - val_loss: 0.1030 - learning_rate: 4.7239e-06
# Starting epoch 50
# Epoch 50/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 135ms/step - accuracy: 0.9987 - loss: 0.0100 - val_accuracy: 0.9588 - val_loss: 0.1072 - learning_rate: 4.7239e-06
# Starting epoch 51
# Epoch 51/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 136ms/step - accuracy: 0.9975 - loss: 0.0129 - val_accuracy: 0.9600 - val_loss: 0.1066 - learning_rate: 4.2515e-06
# Starting epoch 52
# Epoch 52/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 136ms/step - accuracy: 0.9989 - loss: 0.0139 - val_accuracy: 0.9600 - val_loss: 0.1065 - learning_rate: 1.0000e-06
# Starting epoch 53
# Epoch 53/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 137ms/step - accuracy: 0.9982 - loss: 0.0108 - val_accuracy: 0.9600 - val_loss: 0.1063 - learning_rate: 1.0000e-06
# Starting epoch 54
# Epoch 54/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 41s 137ms/step - accuracy: 0.9989 - loss: 0.0117 - val_accuracy: 0.9600 - val_loss: 0.1058 - learning_rate: 1.0000e-06
# Starting epoch 55
# Epoch 55/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 41s 136ms/step - accuracy: 0.9988 - loss: 0.0119 - val_accuracy: 0.9600 - val_loss: 0.1060 - learning_rate: 1.0000e-06
# Starting epoch 56
# Epoch 56/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 137ms/step - accuracy: 0.9978 - loss: 0.0132 - val_accuracy: 0.9600 - val_loss: 0.1058 - learning_rate: 1.0000e-06
# Starting epoch 57
# Epoch 57/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 138ms/step - accuracy: 0.9986 - loss: 0.0116 - val_accuracy: 0.9613 - val_loss: 0.1061 - learning_rate: 1.0000e-06
# Metrics saved to Adam_metrics_InceptionV3.csv
# Metrics saved to summary_metrics_InceptionV3.csv
# Metrics saved to best_optimizer_metrics_Adam_InceptionV3.csv

# %%
summary_df
# Out:
#     Model Name Optimizer  Mean_Train_Loss  Mean_Train_Accuracy  Mean_Val_Loss  \
# 0  InceptionV3      Adam         0.166991             0.934057       0.353447
#
#    Mean_Val_Accuracy  Total_Training_Time_Minutes  Test_Loss  Test_Accuracy
# 0           0.873092                  1691.581223   0.092817          0.975

# %%
display(summary_df)

summary_df.to_csv('hyperparameter.csv', index=False)
# Out:
#     Model Name Optimizer  Mean_Train_Loss  Mean_Train_Accuracy  Mean_Val_Loss  \
# 0  InceptionV3      Adam         0.166991             0.934057       0.353447
#
#    Mean_Val_Accuracy  Total_Training_Time_Minutes  Test_Loss  Test_Accuracy
# 0           0.873092                  1691.581223   0.092817          0.975

# %%
best_metrics_df
# Out:
#      Model Name  epoch  train_loss  train_accuracy  val_loss  val_accuracy  \
# 0   InceptionV3      1    1.308004        0.423594  1.601719       0.53000
# 1   InceptionV3      2    0.829170        0.621094  0.725589       0.66500
# 2   InceptionV3      3    0.730512        0.670469  1.683536       0.41750
# 3   InceptionV3      4    0.666509        0.706875  1.101444       0.52625
# 4   InceptionV3      5    0.605428        0.738750  0.655088       0.69250
# 5   InceptionV3      6    0.555805        0.763906  0.716995       0.62250
# 6   InceptionV3      7    0.520551        0.786875  0.501524       0.77625
# 7   InceptionV3      8    0.483461        0.800937  0.719771       0.71625
# 8   InceptionV3      9    0.439672        0.826563  0.939258       0.65750
# 9   InceptionV3     10    0.393088        0.840781  0.455001       0.81625
# 10  InceptionV3     11    0.368304        0.855625  1.684813       0.55125
# 11  InceptionV3     12    0.321240        0.879062  1.581259       0.57875
# 12  InceptionV3     13    0.315020        0.880938  0.607806       0.78375
# 13  InceptionV3     14    0.293688        0.895469  0.551480       0.80625
# 14  InceptionV3     15    0.267900        0.900312  0.992698       0.62625
# 15  InceptionV3     16    0.164599        0.941875  0.207400       0.92000
# 16  InceptionV3     17    0.114195        0.963750  0.197563       0.92500
# 17  InceptionV3     18    0.095196        0.972188  0.187398       0.93500
# 18  InceptionV3     19    0.084919        0.975937  0.222230       0.91875
# 19  InceptionV3     20    0.079929        0.979062  0.194008       0.93250
# 20  InceptionV3     21    0.073036        0.979062  0.137645       0.95375
# 21  InceptionV3     22    0.052908        0.987813  0.177231       0.94375
# 22  InceptionV3     23    0.059929        0.984688  0.217264       0.92250
# 23  InceptionV3     24    0.053853        0.984375  0.177721       0.94000
# 24  InceptionV3     25    0.057716        0.983281  0.293360       0.90000
# 25  InceptionV3     26    0.046733        0.987500  0.145980       0.94875
# 26  InceptionV3     27    0.034910        0.991875  0.127632       0.95750
# 27  InceptionV3     28    0.026087        0.995000  0.120893       0.95375
# 28  InceptionV3     29    0.025044        0.993906  0.121668       0.95750
# 29  InceptionV3     30    0.024453        0.994844  0.123768       0.95875
# 30  InceptionV3     31    0.021819        0.996562  0.118671       0.95750
# 31  InceptionV3     32    0.024547        0.995938  0.115835       0.96250
# 32  InceptionV3     33    0.021492        0.996250  0.117185       0.96250
# 33  InceptionV3     34    0.016153        0.997500  0.122210       0.95750
# 34  InceptionV3     35    0.024136        0.995156  0.124329       0.95625
# 35  InceptionV3     36    0.024471        0.995313  0.123363       0.95875
# 36  InceptionV3     37    0.017577        0.997187  0.124020       0.96000
# 37  InceptionV3     38    0.018290        0.996719  0.118093       0.96250
# 38  InceptionV3     39    0.012655        0.998438  0.111403       0.96000
# 39  InceptionV3     40    0.014130        0.997656  0.108930       0.96125
# 40  InceptionV3     41    0.012800        0.997969  0.105243       0.96125
# 41  InceptionV3     42    0.014074        0.998281  0.107377       0.95875
# 42  InceptionV3     43    0.016539        0.997344  0.108407       0.95875
# 43  InceptionV3     44    0.015150        0.998281  0.106857       0.96000
# 44  InceptionV3     45    0.017019        0.996562  0.104228       0.96125
# 45  InceptionV3     46    0.014606        0.998125  0.102707       0.96375
# 46  InceptionV3     47    0.012378        0.998750  0.102140       0.96375
# 47  InceptionV3     48    0.016434        0.997187  0.102629       0.96500
# 48  InceptionV3     49    0.012858        0.998438  0.103024       0.96125
# 49  InceptionV3     50    0.010702        0.998438  0.107197       0.95875
# 50  InceptionV3     51    0.012240        0.998125  0.106585       0.96000
# 51  InceptionV3     52    0.012999        0.998750  0.106506       0.96000
# 52  InceptionV3     53    0.011530        0.998594  0.106263       0.96000
# 53  InceptionV3     54    0.013753        0.998594  0.105762       0.96000
# 54  InceptionV3     55    0.012136        0.998750  0.105972       0.96000
# 55  InceptionV3     56    0.013814        0.997500  0.105751       0.96000
# 56  InceptionV3     57    0.012348        0.998438  0.106071       0.96125
#
#     training_time_minutes  test_loss  test_accuracy Optimizer
# 0               29.676864   0.092817          0.975      Adam
# 1               29.676864   0.092817          0.975      Adam
# 2               29.676864   0.092817          0.975      Adam
# 3               29.676864   0.092817          0.975      Adam
# 4               29.676864   0.092817          0.975      Adam
# 5               29.676864   0.092817          0.975      Adam
# 6               29.676864   0.092817          0.975      Adam
# 7               29.676864   0.092817          0.975      Adam
# 8               29.676864   0.092817          0.975      Adam
# 9               29.676864   0.092817          0.975      Adam
# 10              29.676864   0.092817          0.975      Adam
# 11              29.676864   0.092817          0.975      Adam
# 12              29.676864   0.092817          0.975      Adam
# 13              29.676864   0.092817          0.975      Adam
# 14              29.676864   0.092817          0.975      Adam
# 15              29.676864   0.092817          0.975      Adam
# 16              29.676864   0.092817          0.975      Adam
# 17              29.676864   0.092817          0.975      Adam
# 18              29.676864   0.092817          0.975      Adam
# 19              29.676864   0.092817          0.975      Adam
# 20              29.676864   0.092817          0.975      Adam
# 21              29.676864   0.092817          0.975      Adam
# 22              29.676864   0.092817          0.975      Adam
# 23              29.676864   0.092817          0.975      Adam
# 24              29.676864   0.092817          0.975      Adam
# 25              29.676864   0.092817          0.975      Adam
# 26              29.676864   0.092817          0.975      Adam
# 27              29.676864   0.092817          0.975      Adam
# 28              29.676864   0.092817          0.975      Adam
# 29              29.676864   0.092817          0.975      Adam
# 30              29.676864   0.092817          0.975      Adam
# 31              29.676864   0.092817          0.975      Adam
# 32              29.676864   0.092817          0.975      Adam
# 33              29.676864   0.092817          0.975      Adam
# 34              29.676864   0.092817          0.975      Adam
# 35              29.676864   0.092817          0.975      Adam
# 36              29.676864   0.092817          0.975      Adam
# 37              29.676864   0.092817          0.975      Adam
# 38              29.676864   0.092817          0.975      Adam
# 39              29.676864   0.092817          0.975      Adam
# 40              29.676864   0.092817          0.975      Adam
# 41              29.676864   0.092817          0.975      Adam
# 42              29.676864   0.092817          0.975      Adam
# 43              29.676864   0.092817          0.975      Adam
# 44              29.676864   0.092817          0.975      Adam
# 45              29.676864   0.092817          0.975      Adam
# 46              29.676864   0.092817          0.975      Adam
# 47              29.676864   0.092817          0.975      Adam
# 48              29.676864   0.092817          0.975      Adam
# 49              29.676864   0.092817          0.975      Adam
# 50              29.676864   0.092817          0.975      Adam
# 51              29.676864   0.092817          0.975      Adam
# 52              29.676864   0.092817          0.975      Adam
# 53              29.676864   0.092817          0.975      Adam
# 54              29.676864   0.092817          0.975      Adam
# 55              29.676864   0.092817          0.975      Adam
# 56              29.676864   0.092817          0.975      Adam

# %% [markdown]
# # Evaluation

# %%
# evaluate model

from tensorflow.keras.models import load_model

model = load_model('./best_model.keras')
evaluation = model.evaluate(train_generator)
evaluation = model.evaluate(val_generator)
evaluation = model.evaluate(test_generator)
# Out:
#   3/200 ━━━━━━━━━━━━━━━━━━━━ 17s 90ms/step - accuracy: 1.0000 - loss: 0.0026
# W0000 00:00:1720973725.058727      99 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 33s 132ms/step - accuracy: 0.9991 - loss: 0.0055
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9613 - loss: 0.1223
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9718 - loss: 0.0915

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.preprocessing import LabelEncoder

def load_data(dataset_path):
    # Paths to train, val, and test directories
    train_path = os.path.join(dataset_path, 'train')
    val_path = os.path.join(dataset_path, 'val')
    test_path = os.path.join(dataset_path, 'test')

    # Function to load images from a directory
    def load_images_from_dir(dir_path, img_size=(128, 128)):  # Adjust size as needed
        images = []
        labels = []
        for class_name in os.listdir(dir_path):
            class_path = os.path.join(dir_path, class_name)
            if os.path.isdir(class_path):
                for img_name in os.listdir(class_path):
                    img_path = os.path.join(class_path, img_name)
                    img = load_img(img_path, target_size=img_size)
                    img_array = img_to_array(img)
                    images.append(img_array)
                    labels.append(class_name)
        return np.array(images), np.array(labels)

    # Load images and labels
    X_train, y_train = load_images_from_dir(train_path)
    X_val, y_val = load_images_from_dir(val_path)
    X_test, y_test = load_images_from_dir(test_path)

    # Normalize the images
    X_train = X_train / 255.0
    X_val = X_val / 255.0
    X_test = X_test / 255.0

    # Encode the labels
    le = LabelEncoder()
    y_train = le.fit_transform(y_train)
    y_val = le.transform(y_val)
    y_test = le.transform(y_test)

    # Save the label encoder for future use
    np.save('label_encoder_classes.npy', le.classes_)

    # Print some information
    print(f"Number of training samples: {len(X_train)}")
    print(f"Number of validation samples: {len(X_val)}")
    print(f"Number of testing samples: {len(X_test)}")
    print(f"Number of classes: {len(le.classes_)}")
    print(f"Class labels: {le.classes_}")

    return X_train, y_train, X_val, y_val, X_test, y_test,le.classes_

# Usage:
dataset_path = './Dataset'  # Replace with your actual path
X_train, y_train, X_val, y_val, X_test, y_test,classes = load_data(dataset_path)
# Out:
# Number of training samples: 6400
# Number of validation samples: 800
# Number of testing samples: 800
# Number of classes: 4
# Class labels: ['MildDemented' 'ModerateDemented' 'NonDemented' 'VeryMildDemented']

# %%
import numpy as np
import pandas as pd
import os
from time import time
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    cohen_kappa_score, log_loss, brier_score_loss,
    classification_report, confusion_matrix, roc_curve, auc,
    roc_auc_score
)
from sklearn.preprocessing import label_binarize

from keras.models import load_model
from keras.losses import categorical_crossentropy
from keras.utils import to_categorical

# %%
# Model Information
model_name = model_name 
num_layers = len(model.layers)
trainable_params = model.count_params()
non_trainable_params = sum([np.prod(v.shape) for v in model.non_trainable_weights])
activation_functions = 'Softmax'  # Typically used for multiclass



model_architecture = {
    'Model Name': model_name,
    'Number of Layers': num_layers,
    'Trainable Parameters': trainable_params,
    'Non-Trainable Parameters': non_trainable_params,
    'Activation Functions': activation_functions
}

df_architecture = pd.DataFrame([model_architecture])
df_architecture
# Out:
#     Model Name  Number of Layers  Trainable Parameters  \
# 0  InceptionV3               319              22328564
#
#    Non-Trainable Parameters Activation Functions
# 0                     34592              Softmax

# %% [markdown]
# Training Config

# %%
optimizer = best_optimizer  # Assuming this is defined elsewhere
loss_function = 'Categorical Crossentropy'
time_taken_minutes = metrics['training_time_minutes'][-1]
final_epoch = best_metrics_df['epoch'].values[-1] 

# 2. Training Configuration
training_config = {
    'Optimizer': optimizer,
    'Loss Function': loss_function,
    'Final Epoch': final_epoch,
    'Training Time (minutes)': time_taken_minutes
}
df_training = pd.DataFrame([training_config])
df_training
# Out:
#   Optimizer             Loss Function  Final Epoch  Training Time (minutes)
# 0      Adam  Categorical Crossentropy           57                29.676864

# %% [markdown]
# Main Performance Metrics

# %%
num_classes = len(folders)
# Convert test labels to one-hot encoding
y_test_one_hot = to_categorical(y_test, num_classes)

# Evaluate model on test set
test_loss, test_acc = model.evaluate(X_test, y_test_one_hot, verbose=1)

# Make predictions
y_pred_probabilities = model.predict(X_test)
y_pred = np.argmax(y_pred_probabilities, axis=1)

# Get the number of classes
n_classes = y_pred_probabilities.shape[1]

# Compute metrics
accuracy = accuracy_score(y_test, y_pred)
precision_macro = precision_score(y_test, y_pred, average='macro')
recall_macro = recall_score(y_test, y_pred, average='macro')
f1_macro = f1_score(y_test, y_pred, average='macro')
precision_weighted = precision_score(y_test, y_pred, average='weighted')
recall_weighted = recall_score(y_test, y_pred, average='weighted')
f1_weighted = f1_score(y_test, y_pred, average='weighted')
cohen_kappa = cohen_kappa_score(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Precision Macro: {precision_macro}")
print(f"Recall Macro: {recall_macro}")
print(f"F1 Macro: {f1_macro}")
print(" ")
print(f"Precision Weighted: {precision_weighted}")
print(f"Recall Weighted: {recall_weighted}")
print(f"F1 Weighted: {f1_weighted}")

print(f"Cohen Kappa: {cohen_kappa}")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9803 - loss: 0.0667
#  6/25 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# W0000 00:00:1720973781.179858     100 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step
# Accuracy: 0.9725
# Precision Macro: 0.9726485148514852
# Recall Macro: 0.9724999999999999
# F1 Macro: 0.9725621265531639
#
# Precision Weighted: 0.9726485148514851
# Recall Weighted: 0.9725
# F1 Weighted: 0.9725621265531638
# Cohen Kappa: 0.9633333333333334

# %% [markdown]
# Probability based metrics

# %%
# Log loss (requires probabilities)
log_loss_value = log_loss(y_test, y_pred_probabilities)

# Brier score (requires binarized labels for multiclass)
y_test_bin = label_binarize(y_test, classes=range(n_classes))
brier_score = brier_score_loss(y_test_bin.ravel(), y_pred_probabilities.ravel())

# ROC AUC score (One-vs-Rest)
roc_auc_ovr = roc_auc_score(y_test_bin, y_pred_probabilities, multi_class='ovr', average='macro')


print(f"The Log Loss Value: {log_loss_value}")
print(f"Brier Score: {brier_score}")
print(f"ROC-AUC overall: {roc_auc_ovr}")
# Out:
# The Log Loss Value: 0.09419980202310851
# Brier Score: 0.010955561528667557
# ROC-AUC overall: 0.9965104166666666

# %% [markdown]
# Model Size and inference

# %%
# Model Size (MB)
model_size_mb = os.path.getsize('./best_model.keras') / (1024 * 1024)

# Inference Time (ms) - Average over 100 runs
inference_times = []
for _ in range(100):
    start = time()
    model.predict(X_test[:1])  # Predict on a single sample
    inference_times.append(time() - start)
inference_time_ms = np.mean(inference_times) * 1000
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %% [markdown]
# Per class metrics and confusion matrix

# %%
class_names = classes

# Per-Class Metrics
class_report = classification_report(y_test, y_pred, target_names=class_names, output_dict=True)

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot Confusion Matrix
# plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.savefig('multiclass_confusion_matrix.png')
plt.show()

# %%
performance_overview = {
    'Test Accuracy': test_acc,
    'Test Loss': test_loss,
    'Overall Accuracy': accuracy,
    'Cohen\'s Kappa': cohen_kappa,
    'Log Loss': log_loss_value,
    'Brier Score': brier_score
}

df_overview = pd.DataFrame([performance_overview])
df_overview
# Out:
#    Test Accuracy  Test Loss  Overall Accuracy  Cohen's Kappa  Log Loss  \
# 0         0.9725     0.0942            0.9725       0.963333    0.0942
#
#    Brier Score
# 0     0.010956

# %%
class_agnostic_metrics = {
    'Precision (Macro)': precision_macro,
    'Recall (Macro)': recall_macro,
    'F1-score (Macro)': f1_macro,
    'Precision (Weighted)': precision_weighted,
    'Recall (Weighted)': recall_weighted,
    'F1-score (Weighted)': f1_weighted,
    'ROC AUC (OvR, Macro)': roc_auc_ovr
}

df_class_agnostic = pd.DataFrame([class_agnostic_metrics])
df_class_agnostic
# Out:
#    Precision (Macro)  Recall (Macro)  F1-score (Macro)  Precision (Weighted)  \
# 0           0.972649          0.9725          0.972562              0.972649
#
#    Recall (Weighted)  F1-score (Weighted)  ROC AUC (OvR, Macro)
# 0             0.9725             0.972562               0.99651

# %%
# 5. Per-Class Metrics
per_class_metrics = {}
for i, class_name in enumerate(class_report.keys()):
    if class_name not in ['accuracy', 'macro avg', 'weighted avg']:
        class_dict = {
            f'Precision (Class {i})': class_report[class_name]['precision'],
            f'Recall (Class {i})': class_report[class_name]['recall'],
            f'F1-score (Class {i})': class_report[class_name]['f1-score'],
            f'Support (Class {i})': class_report[class_name]['support'],
            f'True Positives (Class {i})': conf_matrix[i, i]
        }
        per_class_metrics.update(class_dict)

df_per_class = pd.DataFrame([per_class_metrics])
df_per_class
# Out:
#    Precision (Class 0)  Recall (Class 0)  F1-score (Class 0)  \
# 0                  1.0              0.99            0.994975
#
#    Support (Class 0)  True Positives (Class 0)  Precision (Class 1)  \
# 0                200                       198                  1.0
#
#    Recall (Class 1)  F1-score (Class 1)  Support (Class 1)  \
# 0               1.0                 1.0                200
#
#    True Positives (Class 1)  Precision (Class 2)  Recall (Class 2)  \
# 0                       200                 0.95              0.95
#
#    F1-score (Class 2)  Support (Class 2)  True Positives (Class 2)  \
# 0                0.95                200                       190
#
#    Precision (Class 3)  Recall (Class 3)  F1-score (Class 3)  \
# 0             0.940594              0.95            0.945274
#
#    Support (Class 3)  True Positives (Class 3)
# 0                200                       190

# %%
# 6. Confusion Matrix Insights
confusion_matrix_insights = {}
for i in range(n_classes):
    for j in range(n_classes):
        if j != i:
            confusion_matrix_insights[f'Misclassified as Class {j} (from Class {i})'] = conf_matrix[i, j]

            

df_confusion = pd.DataFrame([confusion_matrix_insights])
df_confusion
# Out:
#    Misclassified as Class 1 (from Class 0)  \
# 0                                        0
#
#    Misclassified as Class 2 (from Class 0)  \
# 0                                        0
#
#    Misclassified as Class 3 (from Class 0)  \
# 0                                        2
#
#    Misclassified as Class 0 (from Class 1)  \
# 0                                        0
#
#    Misclassified as Class 2 (from Class 1)  \
# 0                                        0
#
#    Misclassified as Class 3 (from Class 1)  \
# 0                                        0
#
#    Misclassified as Class 0 (from Class 2)  \
# 0                                        0
#
#    Misclassified as Class 1 (from Class 2)  \
# 0                                        0
#
#    Misclassified as Class 3 (from Class 2)  \
# 0                                       10
#
#    Misclassified as Class 0 (from Class 3)  \
# 0                                        0
#
#    Misclassified as Class 1 (from Class 3)  \
# 0                                        0
#
#    Misclassified as Class 2 (from Class 3)
# 0                                       10

# %%
deployment_metrics = {
    'Model Size (MB)': model_size_mb,
    'Inference Time (ms)': inference_time_ms
}

df_deployment = pd.DataFrame([deployment_metrics])
df_deployment
# Out:
#    Model Size (MB)  Inference Time (ms)
# 0       256.391631           156.084194

# %%
# Assuming class names are based on the order of the folders
class_names = classes
n_classes = len(class_names)


avg_misclassification = {}
for i in range(n_classes):
    misclassified = sum(conf_matrix[i][j] for j in range(n_classes) if j != i)
    total = sum(conf_matrix[i])
    class_name = class_names[i]
    avg_misclassification[f'Avg Misclassification Rate ({class_name})'] = misclassified / total

df_misclassification = pd.DataFrame([avg_misclassification])
df_misclassification
# Out:
#    Avg Misclassification Rate (MildDemented)  \
# 0                                       0.01
#
#    Avg Misclassification Rate (ModerateDemented)  \
# 0                                            0.0
#
#    Avg Misclassification Rate (NonDemented)  \
# 0                                      0.05
#
#    Avg Misclassification Rate (VeryMildDemented)
# 0                                           0.05

# %%
# Merge all DataFrames
final_df = pd.concat([
    df_architecture,
    df_training,
    df_overview,
    df_class_agnostic,
    df_per_class, 
#     df_confusion,
    df_deployment,
    df_misclassification
], axis=1)

# Save the final DataFrame to a CSV file
final_df.to_csv('segmented_multiclass_metrics.csv', index=False)

final_df
# Out:
#     Model Name  Number of Layers  Trainable Parameters  \
# 0  InceptionV3               319              22328564
#
#    Non-Trainable Parameters Activation Functions Optimizer  \
# 0                     34592              Softmax      Adam
#
#               Loss Function  Final Epoch  Training Time (minutes)  \
# 0  Categorical Crossentropy           57                29.676864
#
#    Test Accuracy  ...  Recall (Class 3)  F1-score (Class 3)  \
# 0         0.9725  ...              0.95            0.945274
#
#    Support (Class 3)  True Positives (Class 3)  Model Size (MB)  \
# 0                200                       190       256.391631
#
#    Inference Time (ms)  Avg Misclassification Rate (MildDemented)  \
# 0           156.084194                                       0.01
#
#    Avg Misclassification Rate (ModerateDemented)  \
# 0                                            0.0
#
#    Avg Misclassification Rate (NonDemented)  \
# 0                                      0.05
#
#    Avg Misclassification Rate (VeryMildDemented)
# 0                                           0.05
#
# [1 rows x 48 columns]

# %% [markdown]
# Training Informations

# %%
# Binarize the output
from sklearn.preprocessing import label_binarize
y_test_bin = label_binarize(y_test, classes=[0, 1, 2, 3])

# Visualization 2: ROC Curves (One-vs-Rest)
plt.figure(figsize=(10, 6))
for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_test_bin[:, i], y_pred_probabilities[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label=f'ROC curve ({class_names[i]}) (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) - One vs Rest')
plt.legend(loc="lower right")
plt.savefig('multiclass_roc_curves.png')
plt.show()

# %%
# Optional: Save model summary and training history
model.summary(print_fn=lambda x: open('model_summary.txt', 'a').write(x + '\n'))

# Assuming you have training history
history_df = pd.DataFrame(history.history)
history_df.to_csv('training_history.csv', index=False)
history_df
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.423594  1.308004       0.53000  1.601719   9.000000e-04
# 1   0.621094  0.829170       0.66500  0.725589   9.000000e-04
# 2   0.670469  0.730512       0.41750  1.683536   9.000000e-04
# 3   0.706875  0.666509       0.52625  1.101444   9.000000e-04
# 4   0.738750  0.605428       0.69250  0.655088   9.000000e-04
# 5   0.763906  0.555805       0.62250  0.716995   9.000000e-04
# 6   0.786875  0.520551       0.77625  0.501524   9.000000e-04
# 7   0.800937  0.483461       0.71625  0.719771   9.000000e-04
# 8   0.826563  0.439672       0.65750  0.939258   9.000000e-04
# 9   0.840781  0.393088       0.81625  0.455001   9.000000e-04
# 10  0.855625  0.368304       0.55125  1.684813   8.100001e-04
# 11  0.879062  0.321240       0.57875  1.581259   8.100001e-04
# 12  0.880938  0.315020       0.78375  0.607806   8.100001e-04
# 13  0.895469  0.293688       0.80625  0.551480   8.100001e-04
# 14  0.900312  0.267900       0.62625  0.992698   1.620000e-04
# 15  0.941875  0.164599       0.92000  0.207400   1.620000e-04
# 16  0.963750  0.114195       0.92500  0.197563   1.620000e-04
# 17  0.972188  0.095196       0.93500  0.187398   1.620000e-04
# 18  0.975937  0.084919       0.91875  0.222230   1.620000e-04
# 19  0.979062  0.079929       0.93250  0.194008   1.620000e-04
# 20  0.979062  0.073036       0.95375  0.137645   1.458000e-04
# 21  0.987813  0.052908       0.94375  0.177231   1.458000e-04
# 22  0.984688  0.059929       0.92250  0.217264   1.458000e-04
# 23  0.984375  0.053853       0.94000  0.177721   1.458000e-04
# 24  0.983281  0.057716       0.90000  0.293360   1.458000e-04
# 25  0.987500  0.046733       0.94875  0.145980   2.916000e-05
# 26  0.991875  0.034910       0.95750  0.127632   2.916000e-05
# 27  0.995000  0.026087       0.95375  0.120893   2.916000e-05
# 28  0.993906  0.025044       0.95750  0.121668   2.916000e-05
# 29  0.994844  0.024453       0.95875  0.123768   2.916000e-05
# 30  0.996562  0.021819       0.95750  0.118671   2.624400e-05
# 31  0.995938  0.024547       0.96250  0.115835   2.624400e-05
# 32  0.996250  0.021492       0.96250  0.117185   2.624400e-05
# 33  0.997500  0.016153       0.95750  0.122210   2.624400e-05
# 34  0.995156  0.024136       0.95625  0.124329   2.624400e-05
# 35  0.995313  0.024471       0.95875  0.123363   2.624400e-05
# 36  0.997187  0.017577       0.96000  0.124020   5.248800e-06
# 37  0.996719  0.018290       0.96250  0.118093   5.248800e-06
# 38  0.998438  0.012655       0.96000  0.111403   5.248800e-06
# 39  0.997656  0.014130       0.96125  0.108930   5.248800e-06
# 40  0.997969  0.012800       0.96125  0.105243   4.723920e-06
# 41  0.998281  0.014074       0.95875  0.107377   4.723920e-06
# 42  0.997344  0.016539       0.95875  0.108407   4.723920e-06
# 43  0.998281  0.015150       0.96000  0.106857   4.723920e-06
# 44  0.996562  0.017019       0.96125  0.104228   4.723920e-06
# 45  0.998125  0.014606       0.96375  0.102707   4.723920e-06
# 46  0.998750  0.012378       0.96375  0.102140   4.723920e-06
# 47  0.997187  0.016434       0.96500  0.102629   4.723920e-06
# 48  0.998438  0.012858       0.96125  0.103024   4.723920e-06
# 49  0.998438  0.010702       0.95875  0.107197   4.723920e-06
# 50  0.998125  0.012240       0.96000  0.106585   4.251528e-06
# 51  0.998750  0.012999       0.96000  0.106506   1.000000e-06
# 52  0.998594  0.011530       0.96000  0.106263   1.000000e-06
# 53  0.998594  0.013753       0.96000  0.105762   1.000000e-06
# 54  0.998750  0.012136       0.96000  0.105972   1.000000e-06
# 55  0.997500  0.013814       0.96000  0.105751   1.000000e-06
# 56  0.998438  0.012348       0.96125  0.106071   1.000000e-06

# %%
# Plot training history
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# %%
import os
import shutil
import zipfile

# Define the directory containing the files
source_directory = '/kaggle/working/'

# List of file extensions to include
file_extensions = ['.png', '.csv', '.txt','.keras']

# Create a new directory for the selected files
selected_directory = '/kaggle/working/SelectedFiles/'
os.makedirs(selected_directory, exist_ok=True)

# Move the selected files into the new directory
for foldername, subfolders, filenames in os.walk(source_directory):
    for filename in filenames:
        if any(filename.endswith(ext) for ext in file_extensions):
            source_path = os.path.join(foldername, filename)
            destination_path = os.path.join(selected_directory, filename)
            shutil.move(source_path, destination_path)

# Create a ZipFile object
zip_filename = f"{model_name}.zip"
with zipfile.ZipFile(zip_filename, 'w') as zipf:
    # Add the selected directory and its contents to the zip file
    for foldername, _, filenames in os.walk(selected_directory):
        for filename in filenames:
            file_path = os.path.join(foldername, filename)
            zipf.write(file_path, os.path.relpath(file_path, selected_directory))

print(f'{zip_filename} created successfully.')
# Out:
# InceptionV3.zip created successfully.
