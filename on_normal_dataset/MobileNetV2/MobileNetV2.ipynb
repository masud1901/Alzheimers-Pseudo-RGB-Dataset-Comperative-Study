# %% [markdown]
# # Data Collection and Acquisation

# %%
# !pip install split-folders
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl.metadata (6.2 kB)
# Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
import splitfolders

# Path to your dataset
input_folder = '/kaggle/input/alzheimers-synthesized-dataset/dataset/normal_dataset'

# Output folder
output_folder = './Dataset'

# Split the dataset (train: 80%, val: 10%, test: 10%)
splitfolders.ratio(input_folder, output=output_folder, seed=1337, ratio=(.8, .1, .1))
# Out:
# Copying files: 8000 files [01:00, 132.78 files/s]

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
import seaborn as sns
from tensorflow import keras
from sklearn.metrics import confusion_matrix
from keras.layers import Input,Lambda,Dense,Flatten,BatchNormalization,Dropout
from keras import Model
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard
import datetime
# Out:
# 2024-07-14 14:43:01.281346: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-14 14:43:01.281463: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-14 14:43:01.588748: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
#re-sizing all images to this size
IMAGE_SIZE = [128,128]

#training config
epochs = 200
batch_size = 32

# %%
train_path = './Dataset/train'
val_path = './Dataset/val'
test_path = './Dataset/test'

# useful for getting the number of files
image_files = glob(train_path + '/*/*.jp*g')
val_image_files = glob(val_path + '/*/*.jp*g')
test_image_files = glob(test_path + '/*/*.jp*g')

# useful for getting number of classes
folders = glob(train_path + '/*')
num_classes = len(folders)

# %%
train_gen = ImageDataGenerator(
    rescale=1./255,
#     rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)


val_gen = ImageDataGenerator(
 rescale=1./255,
)

test_gen = ImageDataGenerator(
     rescale=1./255,
)

#create generator

train_generator = train_gen.flow_from_directory(
    train_path,
    target_size = IMAGE_SIZE,
    shuffle = True,
    batch_size = batch_size
)

val_generator = val_gen.flow_from_directory(
    val_path,
    target_size = IMAGE_SIZE,
    shuffle = True,
    batch_size = batch_size
)

test_generator = test_gen.flow_from_directory(
    test_path,
    target_size = IMAGE_SIZE,
    shuffle = True,
    batch_size = batch_size
)
# Out:
# Found 6400 images belonging to 4 classes.
# Found 800 images belonging to 4 classes.
# Found 800 images belonging to 4 classes.

# %% [markdown]
# # Modelling

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16, ResNet50, Xception, InceptionV3, MobileNetV2, DenseNet121
from tensorflow.keras.applications.efficientnet import EfficientNetB0
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model

class ModelZoo:
    def __init__(self):
        self.models = {
            'VGG16': VGG16,
            'ResNet50': ResNet50,
            'Xception': Xception,
            'InceptionV3': InceptionV3,
            'MobileNetV2': MobileNetV2,
            'DenseNet121': DenseNet121,
            'EfficientNetB0': EfficientNetB0
        }

    def load_model(self, model_name):
        if model_name not in self.models:
            raise ValueError(f"Model {model_name} not found in model zoo. Available models: {list(self.models.keys())}")
        return self.models[model_name](input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

def create_custom_model(model_name, num_layers_to_train, num_classes, num_dense_units=(64, 16), dropout_rate=0.2, optimizer='adam'):
    """
    Create a custom model based on the specified base model and other parameters.
    """
    model_zoo = ModelZoo()
    base_model = model_zoo.load_model(model_name)

    # Freeze layers
    for layer in base_model.layers:
        layer.trainable = False

    # Set the last num_layers_to_train layers to be trainable
    for layer in base_model.layers[-num_layers_to_train:]:
        layer.trainable = True

    # Flatten the output of the base model
    x = Flatten()(base_model.output)

    # Add dense layers
    for units in num_dense_units:
        x = Dense(units, activation='relu', kernel_initializer='he_uniform')(x)
        x = BatchNormalization()(x)
        x = Dropout(dropout_rate)(x)

    # Final prediction layer
    prediction = Dense(num_classes, activation='softmax', kernel_initializer='glorot_uniform')(x)

    # Create the final model
    custom_model = Model(inputs=base_model.input, outputs=prediction)

    custom_model.compile(
        loss='categorical_crossentropy',
        optimizer=optimizer,
        metrics=['accuracy']
    )

    return custom_model

# %%
            # 'VGG16': VGG16,
            # 'ResNet50': ResNet50,
            # 'Xception': Xception,
            # 'InceptionV3': InceptionV3,
            # 'MobileNetV2': MobileNetV2,
            # 'DenseNet121': DenseNet121,
            # 'EfficientNetB0': EfficientNetB0

model_name = 'MobileNetV2'
selected_model_name = model_name
num_layers_to_train = 0

model = create_custom_model(model_name, num_layers_to_train, num_classes=num_classes)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 64, 64,    │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 64, 64,    │        128 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1_relu (ReLU)   │ (None, 64, 64,    │          0 │ bn_Conv1[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 64, 64,    │        288 │ Conv1_relu[0][0]  │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 64, 64,    │        128 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 64, 64,    │          0 │ expanded_conv_de… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 64, 64,    │        512 │ expanded_conv_de… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 64, 64,    │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand      │ (None, 64, 64,    │      1,536 │ expanded_conv_pr… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_BN   │ (None, 64, 64,    │        384 │ block_1_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_relu │ (None, 64, 64,    │          0 │ block_1_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_pad         │ (None, 65, 65,    │          0 │ block_1_expand_r… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise   │ (None, 32, 32,    │        864 │ block_1_pad[0][0] │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 32, 32,    │        384 │ block_1_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 32, 32,    │          0 │ block_1_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project     │ (None, 32, 32,    │      2,304 │ block_1_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project_BN  │ (None, 32, 32,    │         96 │ block_1_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand      │ (None, 32, 32,    │      3,456 │ block_1_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_BN   │ (None, 32, 32,    │        576 │ block_2_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_relu │ (None, 32, 32,    │          0 │ block_2_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise   │ (None, 32, 32,    │      1,296 │ block_2_expand_r… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 32, 32,    │        576 │ block_2_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 32, 32,    │          0 │ block_2_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project     │ (None, 32, 32,    │      3,456 │ block_2_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project_BN  │ (None, 32, 32,    │         96 │ block_2_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_add (Add)   │ (None, 32, 32,    │          0 │ block_1_project_… │
# │                     │ 24)               │            │ block_2_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand      │ (None, 32, 32,    │      3,456 │ block_2_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_BN   │ (None, 32, 32,    │        576 │ block_3_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_relu │ (None, 32, 32,    │          0 │ block_3_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_pad         │ (None, 33, 33,    │          0 │ block_3_expand_r… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise   │ (None, 16, 16,    │      1,296 │ block_3_pad[0][0] │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 16, 16,    │        576 │ block_3_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 16, 16,    │          0 │ block_3_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project     │ (None, 16, 16,    │      4,608 │ block_3_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project_BN  │ (None, 16, 16,    │        128 │ block_3_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand      │ (None, 16, 16,    │      6,144 │ block_3_project_… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_BN   │ (None, 16, 16,    │        768 │ block_4_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_relu │ (None, 16, 16,    │          0 │ block_4_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise   │ (None, 16, 16,    │      1,728 │ block_4_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 16, 16,    │        768 │ block_4_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 16, 16,    │          0 │ block_4_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project     │ (None, 16, 16,    │      6,144 │ block_4_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project_BN  │ (None, 16, 16,    │        128 │ block_4_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_add (Add)   │ (None, 16, 16,    │          0 │ block_3_project_… │
# │                     │ 32)               │            │ block_4_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand      │ (None, 16, 16,    │      6,144 │ block_4_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_BN   │ (None, 16, 16,    │        768 │ block_5_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_relu │ (None, 16, 16,    │          0 │ block_5_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise   │ (None, 16, 16,    │      1,728 │ block_5_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 16, 16,    │        768 │ block_5_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 16, 16,    │          0 │ block_5_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project     │ (None, 16, 16,    │      6,144 │ block_5_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project_BN  │ (None, 16, 16,    │        128 │ block_5_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_add (Add)   │ (None, 16, 16,    │          0 │ block_4_add[0][0… │
# │                     │ 32)               │            │ block_5_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand      │ (None, 16, 16,    │      6,144 │ block_5_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_BN   │ (None, 16, 16,    │        768 │ block_6_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_relu │ (None, 16, 16,    │          0 │ block_6_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_pad         │ (None, 17, 17,    │          0 │ block_6_expand_r… │
# │ (ZeroPadding2D)     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise   │ (None, 8, 8, 192) │      1,728 │ block_6_pad[0][0] │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 8, 8, 192) │        768 │ block_6_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 8, 8, 192) │          0 │ block_6_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project     │ (None, 8, 8, 64)  │     12,288 │ block_6_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project_BN  │ (None, 8, 8, 64)  │        256 │ block_6_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand      │ (None, 8, 8, 384) │     24,576 │ block_6_project_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_BN   │ (None, 8, 8, 384) │      1,536 │ block_7_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_relu │ (None, 8, 8, 384) │          0 │ block_7_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise   │ (None, 8, 8, 384) │      3,456 │ block_7_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 8, 8, 384) │      1,536 │ block_7_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 8, 8, 384) │          0 │ block_7_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project     │ (None, 8, 8, 64)  │     24,576 │ block_7_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project_BN  │ (None, 8, 8, 64)  │        256 │ block_7_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_add (Add)   │ (None, 8, 8, 64)  │          0 │ block_6_project_… │
# │                     │                   │            │ block_7_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand      │ (None, 8, 8, 384) │     24,576 │ block_7_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_BN   │ (None, 8, 8, 384) │      1,536 │ block_8_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_relu │ (None, 8, 8, 384) │          0 │ block_8_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise   │ (None, 8, 8, 384) │      3,456 │ block_8_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 8, 8, 384) │      1,536 │ block_8_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 8, 8, 384) │          0 │ block_8_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project     │ (None, 8, 8, 64)  │     24,576 │ block_8_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project_BN  │ (None, 8, 8, 64)  │        256 │ block_8_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_add (Add)   │ (None, 8, 8, 64)  │          0 │ block_7_add[0][0… │
# │                     │                   │            │ block_8_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand      │ (None, 8, 8, 384) │     24,576 │ block_8_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_BN   │ (None, 8, 8, 384) │      1,536 │ block_9_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_relu │ (None, 8, 8, 384) │          0 │ block_9_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise   │ (None, 8, 8, 384) │      3,456 │ block_9_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 8, 8, 384) │      1,536 │ block_9_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 8, 8, 384) │          0 │ block_9_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project     │ (None, 8, 8, 64)  │     24,576 │ block_9_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project_BN  │ (None, 8, 8, 64)  │        256 │ block_9_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_add (Add)   │ (None, 8, 8, 64)  │          0 │ block_8_add[0][0… │
# │                     │                   │            │ block_9_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand     │ (None, 8, 8, 384) │     24,576 │ block_9_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_BN  │ (None, 8, 8, 384) │      1,536 │ block_10_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_re… │ (None, 8, 8, 384) │          0 │ block_10_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise  │ (None, 8, 8, 384) │      3,456 │ block_10_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 8, 8, 384) │      1,536 │ block_10_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 8, 8, 384) │          0 │ block_10_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project    │ (None, 8, 8, 96)  │     36,864 │ block_10_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project_BN │ (None, 8, 8, 96)  │        384 │ block_10_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand     │ (None, 8, 8, 576) │     55,296 │ block_10_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_BN  │ (None, 8, 8, 576) │      2,304 │ block_11_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_re… │ (None, 8, 8, 576) │          0 │ block_11_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise  │ (None, 8, 8, 576) │      5,184 │ block_11_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 8, 8, 576) │      2,304 │ block_11_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 8, 8, 576) │          0 │ block_11_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project    │ (None, 8, 8, 96)  │     55,296 │ block_11_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project_BN │ (None, 8, 8, 96)  │        384 │ block_11_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_add (Add)  │ (None, 8, 8, 96)  │          0 │ block_10_project… │
# │                     │                   │            │ block_11_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand     │ (None, 8, 8, 576) │     55,296 │ block_11_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_BN  │ (None, 8, 8, 576) │      2,304 │ block_12_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_re… │ (None, 8, 8, 576) │          0 │ block_12_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise  │ (None, 8, 8, 576) │      5,184 │ block_12_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 8, 8, 576) │      2,304 │ block_12_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 8, 8, 576) │          0 │ block_12_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project    │ (None, 8, 8, 96)  │     55,296 │ block_12_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project_BN │ (None, 8, 8, 96)  │        384 │ block_12_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_add (Add)  │ (None, 8, 8, 96)  │          0 │ block_11_add[0][… │
# │                     │                   │            │ block_12_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand     │ (None, 8, 8, 576) │     55,296 │ block_12_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_BN  │ (None, 8, 8, 576) │      2,304 │ block_13_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_re… │ (None, 8, 8, 576) │          0 │ block_13_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_pad        │ (None, 9, 9, 576) │          0 │ block_13_expand_… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise  │ (None, 4, 4, 576) │      5,184 │ block_13_pad[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 4, 4, 576) │      2,304 │ block_13_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 4, 4, 576) │          0 │ block_13_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project    │ (None, 4, 4, 160) │     92,160 │ block_13_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project_BN │ (None, 4, 4, 160) │        640 │ block_13_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand     │ (None, 4, 4, 960) │    153,600 │ block_13_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_BN  │ (None, 4, 4, 960) │      3,840 │ block_14_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_re… │ (None, 4, 4, 960) │          0 │ block_14_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise  │ (None, 4, 4, 960) │      8,640 │ block_14_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 4, 4, 960) │      3,840 │ block_14_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 4, 4, 960) │          0 │ block_14_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project    │ (None, 4, 4, 160) │    153,600 │ block_14_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project_BN │ (None, 4, 4, 160) │        640 │ block_14_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_add (Add)  │ (None, 4, 4, 160) │          0 │ block_13_project… │
# │                     │                   │            │ block_14_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand     │ (None, 4, 4, 960) │    153,600 │ block_14_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_BN  │ (None, 4, 4, 960) │      3,840 │ block_15_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_re… │ (None, 4, 4, 960) │          0 │ block_15_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise  │ (None, 4, 4, 960) │      8,640 │ block_15_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 4, 4, 960) │      3,840 │ block_15_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 4, 4, 960) │          0 │ block_15_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project    │ (None, 4, 4, 160) │    153,600 │ block_15_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project_BN │ (None, 4, 4, 160) │        640 │ block_15_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_add (Add)  │ (None, 4, 4, 160) │          0 │ block_14_add[0][… │
# │                     │                   │            │ block_15_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand     │ (None, 4, 4, 960) │    153,600 │ block_15_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_BN  │ (None, 4, 4, 960) │      3,840 │ block_16_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_re… │ (None, 4, 4, 960) │          0 │ block_16_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise  │ (None, 4, 4, 960) │      8,640 │ block_16_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 4, 4, 960) │      3,840 │ block_16_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 4, 4, 960) │          0 │ block_16_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project    │ (None, 4, 4, 320) │    307,200 │ block_16_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project_BN │ (None, 4, 4, 320) │      1,280 │ block_16_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1 (Conv2D)     │ (None, 4, 4,      │    409,600 │ block_16_project… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1_bn           │ (None, 4, 4,      │      5,120 │ Conv_1[0][0]      │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_relu (ReLU)     │ (None, 4, 4,      │          0 │ Conv_1_bn[0][0]   │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 20480)     │          0 │ out_relu[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │  1,310,784 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 64)        │        256 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 16)        │      1,040 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16)        │         64 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 16)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 4)         │         68 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,570,196 (13.62 MB)
#  Trainable params: 3,535,924 (13.49 MB)
#  Non-trainable params: 34,272 (133.88 KB)

# %%
from tensorflow.keras.utils import plot_model

# Visualize the model architecture
plot_model(model,
#            show_shapes=True,
#            show_layer_names=True,
           to_file='model.png')

# %% [markdown]
# # Training

# %%
import tensorflow as tf
from keras.callbacks import (
    EarlyStopping,
    ModelCheckpoint,
#     TensorBoard,
    ReduceLROnPlateau,
    CSVLogger,
    LearningRateScheduler,
    Callback
)
import datetime

# Define early stopping
early_stopping = EarlyStopping(monitor="val_loss", patience=10)

# Define model checkpointing
model_checkpoint = ModelCheckpoint(
    "best_model.keras", monitor="val_loss", save_best_only=True
)

# Define TensorBoard callback
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(
    log_dir=log_dir, histogram_freq=1, update_freq="epoch"
)

# Define ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.2, patience=5, min_lr=1e-6)

# Define CSVLogger callback
csv_logger = tf.keras.callbacks.CSVLogger("training.log")


# Define LearningRateScheduler callback
def lr_scheduler(epoch, lr):
    if epoch % 10 == 0:
        return lr * 0.9
    else:
        return lr


lr_scheduler_callback = LearningRateScheduler(lr_scheduler)

class EpochLogger(Callback):
    def on_epoch_begin(self, epoch, logs=None):
        print(f"Starting epoch {epoch + 1}")
        self.current_epoch = epoch + 1

epoch_logger = EpochLogger()

# Combine all callbacks
callbacks = [
    early_stopping,
    model_checkpoint,
#     tensorboard_callback,
    reduce_lr,
    csv_logger,
    lr_scheduler_callback,
    epoch_logger
]

# %%
import time
import pandas as pd
from keras.optimizers import Adam, RMSprop, SGD, Adagrad, Adadelta, Nadam, AdamW

def define_optimizers():
    return {
        "Adam": Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-7, amsgrad=False),
#         "SGD": SGD(learning_rate=0.001, momentum=0.009, nesterov=False),
#         "Adagrad": Adagrad(learning_rate=0.001, epsilon=1e-7),
#         "Adadelta": Adadelta(learning_rate=0.001, rho=0.95, epsilon=1e-7),
#         "Nadam": Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-7),
#         "RMSprop": RMSprop(learning_rate=0.001, rho=0.9, momentum=0.0, epsilon=1e-7),
#         "AdamW": AdamW(learning_rate=1e-3, beta_1=0.9, beta_2=0.999, epsilon=1e-7, weight_decay=1e-2)
    }

def train_and_evaluate(model, train_generator, val_generator, test_generator, callbacks, batch_size):
    start_time = time.time()
    history = model.fit(
        train_generator,
        validation_data=val_generator,
        epochs=epochs,
        callbacks=callbacks,
        batch_size=batch_size,
        verbose=1,
    )
    training_time = (time.time() - start_time) / 60.0
    test_loss, test_accuracy = model.evaluate(test_generator, verbose=0)
    return history, training_time, test_loss, test_accuracy

def collect_metrics(history, training_time, test_loss, test_accuracy, model_name):
    return {
        'Model Name': model_name,
        'epoch': range(1, len(history.history['loss']) + 1),
        'train_loss': history.history['loss'],
        'train_accuracy': history.history['accuracy'],
        'val_loss': history.history['val_loss'],
        'val_accuracy': history.history['val_accuracy'],
        'training_time_minutes': [training_time] * len(history.history['loss']),
        'test_loss': [test_loss] * len(history.history['loss']),
        'test_accuracy': [test_accuracy] * len(history.history['loss'])
    }

def save_metrics(metrics, filename):
    pd.DataFrame(metrics).to_csv(filename, index=False)
    print(f"Metrics saved to {filename}")

def calculate_mean_metrics(metrics):
    return {
        'Model Name': metrics['Model Name'],
        'Optimizer': metrics['Optimizer'],
        'Mean_Train_Loss': np.mean(metrics['train_loss']),
        'Mean_Train_Accuracy': np.mean(metrics['train_accuracy']),
        'Mean_Val_Loss': np.mean(metrics['val_loss']),
        'Mean_Val_Accuracy': np.mean(metrics['val_accuracy']),
        'Total_Training_Time_Minutes': np.sum(metrics['training_time_minutes']),
        'Test_Loss': metrics['test_loss'][0],
        'Test_Accuracy': metrics['test_accuracy'][0]
    }

# %%
optimizers = define_optimizers()
summary_results = []
best_optimizer = None
best_val_accuracy = 0.0

for name, optimizer in optimizers.items():
    model = create_custom_model(model_name, num_layers_to_train, num_classes ,optimizer=optimizer)
    history, training_time, test_loss, test_accuracy = train_and_evaluate(
        model, train_generator, val_generator, test_generator, callbacks, batch_size=256
    )

    metrics = collect_metrics(history, training_time, test_loss, test_accuracy, model_name)
    metrics['Optimizer'] = name
    
    save_metrics(metrics, f"{name}_metrics_{model_name}.csv")
    
    mean_metrics = calculate_mean_metrics(metrics)
    summary_results.append(mean_metrics)

    if test_accuracy > best_val_accuracy:
        best_val_accuracy = test_accuracy
        best_optimizer = name

summary_df = pd.DataFrame(summary_results)
save_metrics(summary_df, f"summary_metrics_{model_name}.csv")

if best_optimizer:
    best_metrics_df = pd.read_csv(f"{best_optimizer}_metrics_{model_name}.csv")
    save_metrics(best_metrics_df, f"best_optimizer_metrics_{best_optimizer}_{model_name}.csv")
# Out:
# Starting epoch 1
# Epoch 1/200
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   2/200 ━━━━━━━━━━━━━━━━━━━━ 12s 63ms/step - accuracy: 0.2734 - loss: 2.0069
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1720968265.614684      99 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1720968265.684834      99 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.4318 - loss: 1.4312
# W0000 00:00:1720968294.873613      97 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 88s 153ms/step - accuracy: 0.4322 - loss: 1.4299 - val_accuracy: 0.4525 - val_loss: 1.3687 - learning_rate: 9.0000e-04
# Starting epoch 2
# Epoch 2/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 133ms/step - accuracy: 0.6445 - loss: 0.8158 - val_accuracy: 0.2500 - val_loss: 5.5944 - learning_rate: 9.0000e-04
# Starting epoch 3
# Epoch 3/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 133ms/step - accuracy: 0.6927 - loss: 0.7228 - val_accuracy: 0.2700 - val_loss: 5.2194 - learning_rate: 9.0000e-04
# Starting epoch 4
# Epoch 4/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 27s 132ms/step - accuracy: 0.7550 - loss: 0.6049 - val_accuracy: 0.2663 - val_loss: 5.9625 - learning_rate: 9.0000e-04
# Starting epoch 5
# Epoch 5/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 27s 132ms/step - accuracy: 0.7636 - loss: 0.5689 - val_accuracy: 0.4913 - val_loss: 2.7929 - learning_rate: 9.0000e-04
# Starting epoch 6
# Epoch 6/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 27s 133ms/step - accuracy: 0.7929 - loss: 0.5246 - val_accuracy: 0.3487 - val_loss: 5.3897 - learning_rate: 1.8000e-04
# Starting epoch 7
# Epoch 7/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 133ms/step - accuracy: 0.8303 - loss: 0.4257 - val_accuracy: 0.6075 - val_loss: 1.5549 - learning_rate: 1.8000e-04
# Starting epoch 8
# Epoch 8/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 136ms/step - accuracy: 0.8749 - loss: 0.3386 - val_accuracy: 0.7500 - val_loss: 0.7430 - learning_rate: 1.8000e-04
# Starting epoch 9
# Epoch 9/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 139ms/step - accuracy: 0.9006 - loss: 0.2770 - val_accuracy: 0.8138 - val_loss: 0.5235 - learning_rate: 1.8000e-04
# Starting epoch 10
# Epoch 10/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 134ms/step - accuracy: 0.9125 - loss: 0.2523 - val_accuracy: 0.8087 - val_loss: 0.5579 - learning_rate: 1.8000e-04
# Starting epoch 11
# Epoch 11/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 137ms/step - accuracy: 0.9194 - loss: 0.2300 - val_accuracy: 0.8562 - val_loss: 0.4368 - learning_rate: 1.6200e-04
# Starting epoch 12
# Epoch 12/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 138ms/step - accuracy: 0.9248 - loss: 0.2218 - val_accuracy: 0.8650 - val_loss: 0.4279 - learning_rate: 1.6200e-04
# Starting epoch 13
# Epoch 13/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 136ms/step - accuracy: 0.9302 - loss: 0.2052 - val_accuracy: 0.8775 - val_loss: 0.3685 - learning_rate: 1.6200e-04
# Starting epoch 14
# Epoch 14/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 136ms/step - accuracy: 0.9365 - loss: 0.1895 - val_accuracy: 0.9075 - val_loss: 0.2632 - learning_rate: 1.6200e-04
# Starting epoch 15
# Epoch 15/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 134ms/step - accuracy: 0.9539 - loss: 0.1486 - val_accuracy: 0.8687 - val_loss: 0.3795 - learning_rate: 1.6200e-04
# Starting epoch 16
# Epoch 16/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 41s 134ms/step - accuracy: 0.9531 - loss: 0.1512 - val_accuracy: 0.8475 - val_loss: 0.4662 - learning_rate: 1.6200e-04
# Starting epoch 17
# Epoch 17/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 134ms/step - accuracy: 0.9462 - loss: 0.1508 - val_accuracy: 0.8375 - val_loss: 0.4627 - learning_rate: 1.6200e-04
# Starting epoch 18
# Epoch 18/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 134ms/step - accuracy: 0.9524 - loss: 0.1410 - val_accuracy: 0.8600 - val_loss: 0.3885 - learning_rate: 1.6200e-04
# Starting epoch 19
# Epoch 19/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 139ms/step - accuracy: 0.9669 - loss: 0.1105 - val_accuracy: 0.9225 - val_loss: 0.2213 - learning_rate: 1.6200e-04
# Starting epoch 20
# Epoch 20/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 135ms/step - accuracy: 0.9637 - loss: 0.1138 - val_accuracy: 0.8750 - val_loss: 0.3316 - learning_rate: 1.6200e-04
# Starting epoch 21
# Epoch 21/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 134ms/step - accuracy: 0.9616 - loss: 0.1271 - val_accuracy: 0.8938 - val_loss: 0.3191 - learning_rate: 1.4580e-04
# Starting epoch 22
# Epoch 22/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 135ms/step - accuracy: 0.9746 - loss: 0.0921 - val_accuracy: 0.9087 - val_loss: 0.2849 - learning_rate: 1.4580e-04
# Starting epoch 23
# Epoch 23/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 140ms/step - accuracy: 0.9760 - loss: 0.0806 - val_accuracy: 0.9388 - val_loss: 0.1913 - learning_rate: 1.4580e-04
# Starting epoch 24
# Epoch 24/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 135ms/step - accuracy: 0.9734 - loss: 0.0917 - val_accuracy: 0.9112 - val_loss: 0.2574 - learning_rate: 1.4580e-04
# Starting epoch 25
# Epoch 25/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 41s 136ms/step - accuracy: 0.9754 - loss: 0.0782 - val_accuracy: 0.9450 - val_loss: 0.2104 - learning_rate: 1.4580e-04
# Starting epoch 26
# Epoch 26/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 135ms/step - accuracy: 0.9761 - loss: 0.0844 - val_accuracy: 0.9175 - val_loss: 0.2630 - learning_rate: 1.4580e-04
# Starting epoch 27
# Epoch 27/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 134ms/step - accuracy: 0.9779 - loss: 0.0757 - val_accuracy: 0.8600 - val_loss: 0.4714 - learning_rate: 1.4580e-04
# Starting epoch 28
# Epoch 28/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 135ms/step - accuracy: 0.9785 - loss: 0.0761 - val_accuracy: 0.9200 - val_loss: 0.2995 - learning_rate: 2.9160e-05
# Starting epoch 29
# Epoch 29/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 139ms/step - accuracy: 0.9845 - loss: 0.0558 - val_accuracy: 0.9475 - val_loss: 0.1843 - learning_rate: 2.9160e-05
# Starting epoch 30
# Epoch 30/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 41s 138ms/step - accuracy: 0.9887 - loss: 0.0414 - val_accuracy: 0.9513 - val_loss: 0.1463 - learning_rate: 2.9160e-05
# Starting epoch 31
# Epoch 31/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 139ms/step - accuracy: 0.9884 - loss: 0.0419 - val_accuracy: 0.9600 - val_loss: 0.1330 - learning_rate: 2.6244e-05
# Starting epoch 32
# Epoch 32/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 137ms/step - accuracy: 0.9945 - loss: 0.0299 - val_accuracy: 0.9613 - val_loss: 0.1183 - learning_rate: 2.6244e-05
# Starting epoch 33
# Epoch 33/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 137ms/step - accuracy: 0.9927 - loss: 0.0314 - val_accuracy: 0.9625 - val_loss: 0.1121 - learning_rate: 2.6244e-05
# Starting epoch 34
# Epoch 34/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 27s 132ms/step - accuracy: 0.9927 - loss: 0.0303 - val_accuracy: 0.9613 - val_loss: 0.1160 - learning_rate: 2.6244e-05
# Starting epoch 35
# Epoch 35/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 136ms/step - accuracy: 0.9940 - loss: 0.0277 - val_accuracy: 0.9638 - val_loss: 0.1005 - learning_rate: 2.6244e-05
# Starting epoch 36
# Epoch 36/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 134ms/step - accuracy: 0.9923 - loss: 0.0334 - val_accuracy: 0.9663 - val_loss: 0.1012 - learning_rate: 2.6244e-05
# Starting epoch 37
# Epoch 37/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 134ms/step - accuracy: 0.9938 - loss: 0.0282 - val_accuracy: 0.9650 - val_loss: 0.1098 - learning_rate: 2.6244e-05
# Starting epoch 38
# Epoch 38/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 137ms/step - accuracy: 0.9946 - loss: 0.0269 - val_accuracy: 0.9663 - val_loss: 0.1005 - learning_rate: 2.6244e-05
# Starting epoch 39
# Epoch 39/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 137ms/step - accuracy: 0.9959 - loss: 0.0215 - val_accuracy: 0.9675 - val_loss: 0.0969 - learning_rate: 2.6244e-05
# Starting epoch 40
# Epoch 40/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 138ms/step - accuracy: 0.9922 - loss: 0.0310 - val_accuracy: 0.9675 - val_loss: 0.0937 - learning_rate: 2.6244e-05
# Starting epoch 41
# Epoch 41/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 27s 132ms/step - accuracy: 0.9949 - loss: 0.0292 - val_accuracy: 0.9625 - val_loss: 0.1313 - learning_rate: 2.3620e-05
# Starting epoch 42
# Epoch 42/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 134ms/step - accuracy: 0.9964 - loss: 0.0217 - val_accuracy: 0.9688 - val_loss: 0.1069 - learning_rate: 2.3620e-05
# Starting epoch 43
# Epoch 43/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 134ms/step - accuracy: 0.9962 - loss: 0.0217 - val_accuracy: 0.9725 - val_loss: 0.0967 - learning_rate: 2.3620e-05
# Starting epoch 44
# Epoch 44/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 136ms/step - accuracy: 0.9968 - loss: 0.0195 - val_accuracy: 0.9675 - val_loss: 0.1040 - learning_rate: 2.3620e-05
# Starting epoch 45
# Epoch 45/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 133ms/step - accuracy: 0.9965 - loss: 0.0178 - val_accuracy: 0.9737 - val_loss: 0.0978 - learning_rate: 4.7239e-06
# Starting epoch 46
# Epoch 46/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 134ms/step - accuracy: 0.9981 - loss: 0.0203 - val_accuracy: 0.9750 - val_loss: 0.0953 - learning_rate: 4.7239e-06
# Starting epoch 47
# Epoch 47/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 138ms/step - accuracy: 0.9975 - loss: 0.0160 - val_accuracy: 0.9762 - val_loss: 0.0860 - learning_rate: 4.7239e-06
# Starting epoch 48
# Epoch 48/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 137ms/step - accuracy: 0.9970 - loss: 0.0167 - val_accuracy: 0.9750 - val_loss: 0.0769 - learning_rate: 4.7239e-06
# Starting epoch 49
# Epoch 49/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 40s 134ms/step - accuracy: 0.9970 - loss: 0.0174 - val_accuracy: 0.9750 - val_loss: 0.0833 - learning_rate: 4.7239e-06
# Starting epoch 50
# Epoch 50/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 137ms/step - accuracy: 0.9975 - loss: 0.0158 - val_accuracy: 0.9750 - val_loss: 0.0827 - learning_rate: 4.7239e-06
# Starting epoch 51
# Epoch 51/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 134ms/step - accuracy: 0.9983 - loss: 0.0141 - val_accuracy: 0.9712 - val_loss: 0.0821 - learning_rate: 4.2515e-06
# Starting epoch 52
# Epoch 52/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 134ms/step - accuracy: 0.9977 - loss: 0.0174 - val_accuracy: 0.9750 - val_loss: 0.0887 - learning_rate: 4.2515e-06
# Starting epoch 53
# Epoch 53/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 134ms/step - accuracy: 0.9982 - loss: 0.0154 - val_accuracy: 0.9725 - val_loss: 0.0823 - learning_rate: 1.0000e-06
# Starting epoch 54
# Epoch 54/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 133ms/step - accuracy: 0.9984 - loss: 0.0138 - val_accuracy: 0.9725 - val_loss: 0.0820 - learning_rate: 1.0000e-06
# Starting epoch 55
# Epoch 55/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 41s 132ms/step - accuracy: 0.9979 - loss: 0.0149 - val_accuracy: 0.9725 - val_loss: 0.0821 - learning_rate: 1.0000e-06
# Starting epoch 56
# Epoch 56/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 41s 131ms/step - accuracy: 0.9975 - loss: 0.0156 - val_accuracy: 0.9737 - val_loss: 0.0809 - learning_rate: 1.0000e-06
# Starting epoch 57
# Epoch 57/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 27s 131ms/step - accuracy: 0.9977 - loss: 0.0135 - val_accuracy: 0.9725 - val_loss: 0.0813 - learning_rate: 1.0000e-06
# Starting epoch 58
# Epoch 58/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 27s 132ms/step - accuracy: 0.9974 - loss: 0.0175 - val_accuracy: 0.9737 - val_loss: 0.0809 - learning_rate: 1.0000e-06
# Metrics saved to Adam_metrics_MobileNetV2.csv
# Metrics saved to summary_metrics_MobileNetV2.csv
# Metrics saved to best_optimizer_metrics_Adam_MobileNetV2.csv

# %%
summary_df
# Out:
#     Model Name Optimizer  Mean_Train_Loss  Mean_Train_Accuracy  Mean_Val_Loss  \
# 0  MobileNetV2      Adam         0.150064             0.944674       0.668692
#
#    Mean_Val_Accuracy  Total_Training_Time_Minutes  Test_Loss  Test_Accuracy
# 0           0.864073                  1700.983905   0.100089        0.97875

# %%
display(summary_df)

summary_df.to_csv('hyperparameter.csv', index=False)
# Out:
#     Model Name Optimizer  Mean_Train_Loss  Mean_Train_Accuracy  Mean_Val_Loss  \
# 0  MobileNetV2      Adam         0.150064             0.944674       0.668692
#
#    Mean_Val_Accuracy  Total_Training_Time_Minutes  Test_Loss  Test_Accuracy
# 0           0.864073                  1700.983905   0.100089        0.97875

# %%
best_metrics_df
# Out:
#      Model Name  epoch  train_loss  train_accuracy  val_loss  val_accuracy  \
# 0   MobileNetV2      1    1.158085        0.514844  1.368717       0.45250
# 1   MobileNetV2      2    0.793927        0.651563  5.594364       0.25000
# 2   MobileNetV2      3    0.687423        0.705000  5.219435       0.27000
# 3   MobileNetV2      4    0.602730        0.748438  5.962537       0.26625
# 4   MobileNetV2      5    0.566133        0.765625  2.792930       0.49125
# 5   MobileNetV2      6    0.523556        0.789062  5.389711       0.34875
# 6   MobileNetV2      7    0.389322        0.848125  1.554904       0.60750
# 7   MobileNetV2      8    0.333755        0.873438  0.743001       0.75000
# 8   MobileNetV2      9    0.280957        0.897969  0.523549       0.81375
# 9   MobileNetV2     10    0.257888        0.909375  0.557902       0.80875
# 10  MobileNetV2     11    0.229420        0.918750  0.436825       0.85625
# 11  MobileNetV2     12    0.211631        0.926875  0.427864       0.86500
# 12  MobileNetV2     13    0.205922        0.929219  0.368504       0.87750
# 13  MobileNetV2     14    0.179465        0.941562  0.263189       0.90750
# 14  MobileNetV2     15    0.159272        0.948594  0.379546       0.86875
# 15  MobileNetV2     16    0.158827        0.949844  0.466175       0.84750
# 16  MobileNetV2     17    0.147214        0.950781  0.462666       0.83750
# 17  MobileNetV2     18    0.142144        0.953125  0.388471       0.86000
# 18  MobileNetV2     19    0.121095        0.963437  0.221336       0.92250
# 19  MobileNetV2     20    0.116933        0.963125  0.331600       0.87500
# 20  MobileNetV2     21    0.119202        0.963906  0.319130       0.89375
# 21  MobileNetV2     22    0.095770        0.972656  0.284884       0.90875
# 22  MobileNetV2     23    0.092782        0.971719  0.191312       0.93875
# 23  MobileNetV2     24    0.085680        0.974219  0.257448       0.91125
# 24  MobileNetV2     25    0.086162        0.973906  0.210390       0.94500
# 25  MobileNetV2     26    0.084101        0.974063  0.262976       0.91750
# 26  MobileNetV2     27    0.078026        0.976875  0.471370       0.86000
# 27  MobileNetV2     28    0.075282        0.979219  0.299520       0.92000
# 28  MobileNetV2     29    0.050872        0.986562  0.184329       0.94750
# 29  MobileNetV2     30    0.038333        0.989844  0.146315       0.95125
# 30  MobileNetV2     31    0.037300        0.990781  0.132973       0.96000
# 31  MobileNetV2     32    0.032633        0.993594  0.118325       0.96125
# 32  MobileNetV2     33    0.031353        0.992344  0.112108       0.96250
# 33  MobileNetV2     34    0.030994        0.992813  0.115956       0.96125
# 34  MobileNetV2     35    0.028782        0.993906  0.100511       0.96375
# 35  MobileNetV2     36    0.031475        0.993750  0.101175       0.96625
# 36  MobileNetV2     37    0.027979        0.994062  0.109799       0.96500
# 37  MobileNetV2     38    0.029734        0.993750  0.100501       0.96625
# 38  MobileNetV2     39    0.023910        0.995313  0.096889       0.96750
# 39  MobileNetV2     40    0.028985        0.992656  0.093721       0.96750
# 40  MobileNetV2     41    0.024224        0.995313  0.131310       0.96250
# 41  MobileNetV2     42    0.020480        0.996094  0.106912       0.96875
# 42  MobileNetV2     43    0.024141        0.996094  0.096666       0.97250
# 43  MobileNetV2     44    0.018741        0.996719  0.104029       0.96750
# 44  MobileNetV2     45    0.019338        0.996094  0.097780       0.97375
# 45  MobileNetV2     46    0.020881        0.997187  0.095295       0.97500
# 46  MobileNetV2     47    0.016552        0.997500  0.086021       0.97625
# 47  MobileNetV2     48    0.018919        0.996250  0.076934       0.97500
# 48  MobileNetV2     49    0.016823        0.996719  0.083276       0.97500
# 49  MobileNetV2     50    0.018652        0.997187  0.082739       0.97500
# 50  MobileNetV2     51    0.015443        0.997813  0.082127       0.97125
# 51  MobileNetV2     52    0.018311        0.997187  0.088656       0.97500
# 52  MobileNetV2     53    0.016505        0.997813  0.082260       0.97250
# 53  MobileNetV2     54    0.013971        0.998281  0.082000       0.97250
# 54  MobileNetV2     55    0.016847        0.997187  0.082134       0.97250
# 55  MobileNetV2     56    0.016260        0.997813  0.080924       0.97375
# 56  MobileNetV2     57    0.016092        0.997187  0.081316       0.97250
# 57  MobileNetV2     58    0.016479        0.997969  0.080872       0.97375
#
#     training_time_minutes  test_loss  test_accuracy Optimizer
# 0               29.327309   0.100089        0.97875      Adam
# 1               29.327309   0.100089        0.97875      Adam
# 2               29.327309   0.100089        0.97875      Adam
# 3               29.327309   0.100089        0.97875      Adam
# 4               29.327309   0.100089        0.97875      Adam
# 5               29.327309   0.100089        0.97875      Adam
# 6               29.327309   0.100089        0.97875      Adam
# 7               29.327309   0.100089        0.97875      Adam
# 8               29.327309   0.100089        0.97875      Adam
# 9               29.327309   0.100089        0.97875      Adam
# 10              29.327309   0.100089        0.97875      Adam
# 11              29.327309   0.100089        0.97875      Adam
# 12              29.327309   0.100089        0.97875      Adam
# 13              29.327309   0.100089        0.97875      Adam
# 14              29.327309   0.100089        0.97875      Adam
# 15              29.327309   0.100089        0.97875      Adam
# 16              29.327309   0.100089        0.97875      Adam
# 17              29.327309   0.100089        0.97875      Adam
# 18              29.327309   0.100089        0.97875      Adam
# 19              29.327309   0.100089        0.97875      Adam
# 20              29.327309   0.100089        0.97875      Adam
# 21              29.327309   0.100089        0.97875      Adam
# 22              29.327309   0.100089        0.97875      Adam
# 23              29.327309   0.100089        0.97875      Adam
# 24              29.327309   0.100089        0.97875      Adam
# 25              29.327309   0.100089        0.97875      Adam
# 26              29.327309   0.100089        0.97875      Adam
# 27              29.327309   0.100089        0.97875      Adam
# 28              29.327309   0.100089        0.97875      Adam
# 29              29.327309   0.100089        0.97875      Adam
# 30              29.327309   0.100089        0.97875      Adam
# 31              29.327309   0.100089        0.97875      Adam
# 32              29.327309   0.100089        0.97875      Adam
# 33              29.327309   0.100089        0.97875      Adam
# 34              29.327309   0.100089        0.97875      Adam
# 35              29.327309   0.100089        0.97875      Adam
# 36              29.327309   0.100089        0.97875      Adam
# 37              29.327309   0.100089        0.97875      Adam
# 38              29.327309   0.100089        0.97875      Adam
# 39              29.327309   0.100089        0.97875      Adam
# 40              29.327309   0.100089        0.97875      Adam
# 41              29.327309   0.100089        0.97875      Adam
# 42              29.327309   0.100089        0.97875      Adam
# 43              29.327309   0.100089        0.97875      Adam
# 44              29.327309   0.100089        0.97875      Adam
# 45              29.327309   0.100089        0.97875      Adam
# 46              29.327309   0.100089        0.97875      Adam
# 47              29.327309   0.100089        0.97875      Adam
# 48              29.327309   0.100089        0.97875      Adam
# 49              29.327309   0.100089        0.97875      Adam
# 50              29.327309   0.100089        0.97875      Adam
# 51              29.327309   0.100089        0.97875      Adam
# 52              29.327309   0.100089        0.97875      Adam
# 53              29.327309   0.100089        0.97875      Adam
# 54              29.327309   0.100089        0.97875      Adam
# 55              29.327309   0.100089        0.97875      Adam
# 56              29.327309   0.100089        0.97875      Adam
# 57              29.327309   0.100089        0.97875      Adam

# %% [markdown]
# # Evaluation

# %%
# evaluate model

from tensorflow.keras.models import load_model

model = load_model('./best_model.keras')
evaluation = model.evaluate(train_generator)
evaluation = model.evaluate(val_generator)
evaluation = model.evaluate(test_generator)
# Out:
#   3/200 ━━━━━━━━━━━━━━━━━━━━ 14s 71ms/step - accuracy: 1.0000 - loss: 0.0019
# W0000 00:00:1720969984.820520      99 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 128ms/step - accuracy: 0.9994 - loss: 0.0031
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9761 - loss: 0.0743
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9773 - loss: 0.1251

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.preprocessing import LabelEncoder

def load_data(dataset_path):
    # Paths to train, val, and test directories
    train_path = os.path.join(dataset_path, 'train')
    val_path = os.path.join(dataset_path, 'val')
    test_path = os.path.join(dataset_path, 'test')

    # Function to load images from a directory
    def load_images_from_dir(dir_path, img_size=(128, 128)):  # Adjust size as needed
        images = []
        labels = []
        for class_name in os.listdir(dir_path):
            class_path = os.path.join(dir_path, class_name)
            if os.path.isdir(class_path):
                for img_name in os.listdir(class_path):
                    img_path = os.path.join(class_path, img_name)
                    img = load_img(img_path, target_size=img_size)
                    img_array = img_to_array(img)
                    images.append(img_array)
                    labels.append(class_name)
        return np.array(images), np.array(labels)

    # Load images and labels
    X_train, y_train = load_images_from_dir(train_path)
    X_val, y_val = load_images_from_dir(val_path)
    X_test, y_test = load_images_from_dir(test_path)

    # Normalize the images
    X_train = X_train / 255.0
    X_val = X_val / 255.0
    X_test = X_test / 255.0

    # Encode the labels
    le = LabelEncoder()
    y_train = le.fit_transform(y_train)
    y_val = le.transform(y_val)
    y_test = le.transform(y_test)

    # Save the label encoder for future use
    np.save('label_encoder_classes.npy', le.classes_)

    # Print some information
    print(f"Number of training samples: {len(X_train)}")
    print(f"Number of validation samples: {len(X_val)}")
    print(f"Number of testing samples: {len(X_test)}")
    print(f"Number of classes: {len(le.classes_)}")
    print(f"Class labels: {le.classes_}")

    return X_train, y_train, X_val, y_val, X_test, y_test,le.classes_

# Usage:
dataset_path = './Dataset'  # Replace with your actual path
X_train, y_train, X_val, y_val, X_test, y_test,classes = load_data(dataset_path)
# Out:
# Number of training samples: 6400
# Number of validation samples: 800
# Number of testing samples: 800
# Number of classes: 4
# Class labels: ['MildDemented' 'ModerateDemented' 'NonDemented' 'VeryMildDemented']

# %%
import numpy as np
import pandas as pd
import os
from time import time
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    cohen_kappa_score, log_loss, brier_score_loss,
    classification_report, confusion_matrix, roc_curve, auc,
    roc_auc_score
)
from sklearn.preprocessing import label_binarize

from keras.models import load_model
from keras.losses import categorical_crossentropy
from keras.utils import to_categorical

# %%
# Model Information
model_name = model_name 
num_layers = len(model.layers)
trainable_params = model.count_params()
non_trainable_params = sum([np.prod(v.shape) for v in model.non_trainable_weights])
activation_functions = 'Softmax'  # Typically used for multiclass



model_architecture = {
    'Model Name': model_name,
    'Number of Layers': num_layers,
    'Trainable Parameters': trainable_params,
    'Non-Trainable Parameters': non_trainable_params,
    'Activation Functions': activation_functions
}

df_architecture = pd.DataFrame([model_architecture])
df_architecture
# Out:
#     Model Name  Number of Layers  Trainable Parameters  \
# 0  MobileNetV2               162               3570196
#
#    Non-Trainable Parameters Activation Functions
# 0                     34272              Softmax

# %% [markdown]
# Training Config

# %%
optimizer = best_optimizer  # Assuming this is defined elsewhere
loss_function = 'Categorical Crossentropy'
time_taken_minutes = metrics['training_time_minutes'][-1]
final_epoch = best_metrics_df['epoch'].values[-1] 

# 2. Training Configuration
training_config = {
    'Optimizer': optimizer,
    'Loss Function': loss_function,
    'Final Epoch': final_epoch,
    'Training Time (minutes)': time_taken_minutes
}
df_training = pd.DataFrame([training_config])
df_training
# Out:
#   Optimizer             Loss Function  Final Epoch  Training Time (minutes)
# 0      Adam  Categorical Crossentropy           58                29.327309

# %% [markdown]
# Main Performance Metrics

# %%
num_classes = len(folders)
# Convert test labels to one-hot encoding
y_test_one_hot = to_categorical(y_test, num_classes)

# Evaluate model on test set
test_loss, test_acc = model.evaluate(X_test, y_test_one_hot, verbose=1)

# Make predictions
y_pred_probabilities = model.predict(X_test)
y_pred = np.argmax(y_pred_probabilities, axis=1)

# Get the number of classes
n_classes = y_pred_probabilities.shape[1]

# Compute metrics
accuracy = accuracy_score(y_test, y_pred)
precision_macro = precision_score(y_test, y_pred, average='macro')
recall_macro = recall_score(y_test, y_pred, average='macro')
f1_macro = f1_score(y_test, y_pred, average='macro')
precision_weighted = precision_score(y_test, y_pred, average='weighted')
recall_weighted = recall_score(y_test, y_pred, average='weighted')
f1_weighted = f1_score(y_test, y_pred, average='weighted')
cohen_kappa = cohen_kappa_score(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Precision Macro: {precision_macro}")
print(f"Recall Macro: {recall_macro}")
print(f"F1 Macro: {f1_macro}")
print(" ")
print(f"Precision Weighted: {precision_weighted}")
print(f"Recall Weighted: {recall_weighted}")
print(f"F1 Weighted: {f1_weighted}")

print(f"Cohen Kappa: {cohen_kappa}")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9845 - loss: 0.0779
# 16/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# W0000 00:00:1720970036.662377      97 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step
# Accuracy: 0.97875
# Precision Macro: 0.9790639474077394
# Recall Macro: 0.97875
# F1 Macro: 0.97877888887774
#
# Precision Weighted: 0.9790639474077395
# Recall Weighted: 0.97875
# F1 Weighted: 0.9787788888777402
# Cohen Kappa: 0.9716666666666667

# %% [markdown]
# Probability based metrics

# %%
# Log loss (requires probabilities)
log_loss_value = log_loss(y_test, y_pred_probabilities)

# Brier score (requires binarized labels for multiclass)
y_test_bin = label_binarize(y_test, classes=range(n_classes))
brier_score = brier_score_loss(y_test_bin.ravel(), y_pred_probabilities.ravel())

# ROC AUC score (One-vs-Rest)
roc_auc_ovr = roc_auc_score(y_test_bin, y_pred_probabilities, multi_class='ovr', average='macro')


print(f"The Log Loss Value: {log_loss_value}")
print(f"Brier Score: {brier_score}")
print(f"ROC-AUC overall: {roc_auc_ovr}")
# Out:
# The Log Loss Value: 0.1023382598130419
# Brier Score: 0.009791409051396567
# ROC-AUC overall: 0.99498125

# %% [markdown]
# Model Size and inference

# %%
# Model Size (MB)
model_size_mb = os.path.getsize('./best_model.keras') / (1024 * 1024)

# Inference Time (ms) - Average over 100 runs
inference_times = []
for _ in range(100):
    start = time()
    model.predict(X_test[:1])  # Predict on a single sample
    inference_times.append(time() - start)
inference_time_ms = np.mean(inference_times) * 1000
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %% [markdown]
# Per class metrics and confusion matrix

# %%
class_names = classes

# Per-Class Metrics
class_report = classification_report(y_test, y_pred, target_names=class_names, output_dict=True)

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot Confusion Matrix
# plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.savefig('multiclass_confusion_matrix.png')
plt.show()

# %%
performance_overview = {
    'Test Accuracy': test_acc,
    'Test Loss': test_loss,
    'Overall Accuracy': accuracy,
    'Cohen\'s Kappa': cohen_kappa,
    'Log Loss': log_loss_value,
    'Brier Score': brier_score
}

df_overview = pd.DataFrame([performance_overview])
df_overview
# Out:
#    Test Accuracy  Test Loss  Overall Accuracy  Cohen's Kappa  Log Loss  \
# 0        0.97875   0.102338           0.97875       0.971667  0.102338
#
#    Brier Score
# 0     0.009791

# %%
class_agnostic_metrics = {
    'Precision (Macro)': precision_macro,
    'Recall (Macro)': recall_macro,
    'F1-score (Macro)': f1_macro,
    'Precision (Weighted)': precision_weighted,
    'Recall (Weighted)': recall_weighted,
    'F1-score (Weighted)': f1_weighted,
    'ROC AUC (OvR, Macro)': roc_auc_ovr
}

df_class_agnostic = pd.DataFrame([class_agnostic_metrics])
df_class_agnostic
# Out:
#    Precision (Macro)  Recall (Macro)  F1-score (Macro)  Precision (Weighted)  \
# 0           0.979064         0.97875          0.978779              0.979064
#
#    Recall (Weighted)  F1-score (Weighted)  ROC AUC (OvR, Macro)
# 0            0.97875             0.978779              0.994981

# %%
# 5. Per-Class Metrics
per_class_metrics = {}
for i, class_name in enumerate(class_report.keys()):
    if class_name not in ['accuracy', 'macro avg', 'weighted avg']:
        class_dict = {
            f'Precision (Class {i})': class_report[class_name]['precision'],
            f'Recall (Class {i})': class_report[class_name]['recall'],
            f'F1-score (Class {i})': class_report[class_name]['f1-score'],
            f'Support (Class {i})': class_report[class_name]['support'],
            f'True Positives (Class {i})': conf_matrix[i, i]
        }
        per_class_metrics.update(class_dict)

df_per_class = pd.DataFrame([per_class_metrics])
df_per_class
# Out:
#    Precision (Class 0)  Recall (Class 0)  F1-score (Class 0)  \
# 0                  1.0             0.995            0.997494
#
#    Support (Class 0)  True Positives (Class 0)  Precision (Class 1)  \
# 0                200                       199                  1.0
#
#    Recall (Class 1)  F1-score (Class 1)  Support (Class 1)  \
# 0               1.0                 1.0                200
#
#    True Positives (Class 1)  Precision (Class 2)  Recall (Class 2)  \
# 0                       200             0.942029             0.975
#
#    F1-score (Class 2)  Support (Class 2)  True Positives (Class 2)  \
# 0            0.958231                200                       195
#
#    Precision (Class 3)  Recall (Class 3)  F1-score (Class 3)  \
# 0             0.974227             0.945            0.959391
#
#    Support (Class 3)  True Positives (Class 3)
# 0                200                       189

# %%
# 6. Confusion Matrix Insights
confusion_matrix_insights = {}
for i in range(n_classes):
    for j in range(n_classes):
        if j != i:
            confusion_matrix_insights[f'Misclassified as Class {j} (from Class {i})'] = conf_matrix[i, j]

            

df_confusion = pd.DataFrame([confusion_matrix_insights])
df_confusion
# Out:
#    Misclassified as Class 1 (from Class 0)  \
# 0                                        0
#
#    Misclassified as Class 2 (from Class 0)  \
# 0                                        1
#
#    Misclassified as Class 3 (from Class 0)  \
# 0                                        0
#
#    Misclassified as Class 0 (from Class 1)  \
# 0                                        0
#
#    Misclassified as Class 2 (from Class 1)  \
# 0                                        0
#
#    Misclassified as Class 3 (from Class 1)  \
# 0                                        0
#
#    Misclassified as Class 0 (from Class 2)  \
# 0                                        0
#
#    Misclassified as Class 1 (from Class 2)  \
# 0                                        0
#
#    Misclassified as Class 3 (from Class 2)  \
# 0                                        5
#
#    Misclassified as Class 0 (from Class 3)  \
# 0                                        0
#
#    Misclassified as Class 1 (from Class 3)  \
# 0                                        0
#
#    Misclassified as Class 2 (from Class 3)
# 0                                       11

# %%
deployment_metrics = {
    'Model Size (MB)': model_size_mb,
    'Inference Time (ms)': inference_time_ms
}

df_deployment = pd.DataFrame([deployment_metrics])
df_deployment
# Out:
#    Model Size (MB)  Inference Time (ms)
# 0        41.244033           104.280584

# %%
# Assuming class names are based on the order of the folders
class_names = classes
n_classes = len(class_names)


avg_misclassification = {}
for i in range(n_classes):
    misclassified = sum(conf_matrix[i][j] for j in range(n_classes) if j != i)
    total = sum(conf_matrix[i])
    class_name = class_names[i]
    avg_misclassification[f'Avg Misclassification Rate ({class_name})'] = misclassified / total

df_misclassification = pd.DataFrame([avg_misclassification])
df_misclassification
# Out:
#    Avg Misclassification Rate (MildDemented)  \
# 0                                      0.005
#
#    Avg Misclassification Rate (ModerateDemented)  \
# 0                                            0.0
#
#    Avg Misclassification Rate (NonDemented)  \
# 0                                     0.025
#
#    Avg Misclassification Rate (VeryMildDemented)
# 0                                          0.055

# %%
# Merge all DataFrames
final_df = pd.concat([
    df_architecture,
    df_training,
    df_overview,
    df_class_agnostic,
    df_per_class, 
#     df_confusion,
    df_deployment,
    df_misclassification
], axis=1)

# Save the final DataFrame to a CSV file
final_df.to_csv('segmented_multiclass_metrics.csv', index=False)

final_df
# Out:
#     Model Name  Number of Layers  Trainable Parameters  \
# 0  MobileNetV2               162               3570196
#
#    Non-Trainable Parameters Activation Functions Optimizer  \
# 0                     34272              Softmax      Adam
#
#               Loss Function  Final Epoch  Training Time (minutes)  \
# 0  Categorical Crossentropy           58                29.327309
#
#    Test Accuracy  ...  Recall (Class 3)  F1-score (Class 3)  \
# 0        0.97875  ...             0.945            0.959391
#
#    Support (Class 3)  True Positives (Class 3)  Model Size (MB)  \
# 0                200                       189        41.244033
#
#    Inference Time (ms)  Avg Misclassification Rate (MildDemented)  \
# 0           104.280584                                      0.005
#
#    Avg Misclassification Rate (ModerateDemented)  \
# 0                                            0.0
#
#    Avg Misclassification Rate (NonDemented)  \
# 0                                     0.025
#
#    Avg Misclassification Rate (VeryMildDemented)
# 0                                          0.055
#
# [1 rows x 48 columns]

# %% [markdown]
# Training Informations

# %%
# Binarize the output
from sklearn.preprocessing import label_binarize
y_test_bin = label_binarize(y_test, classes=[0, 1, 2, 3])

# Visualization 2: ROC Curves (One-vs-Rest)
plt.figure(figsize=(10, 6))
for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_test_bin[:, i], y_pred_probabilities[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label=f'ROC curve ({class_names[i]}) (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) - One vs Rest')
plt.legend(loc="lower right")
plt.savefig('multiclass_roc_curves.png')
plt.show()

# %%
# Optional: Save model summary and training history
model.summary(print_fn=lambda x: open('model_summary.txt', 'a').write(x + '\n'))

# Assuming you have training history
history_df = pd.DataFrame(history.history)
history_df.to_csv('training_history.csv', index=False)
history_df
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.514844  1.158085       0.45250  1.368717   9.000000e-04
# 1   0.651563  0.793927       0.25000  5.594364   9.000000e-04
# 2   0.705000  0.687423       0.27000  5.219435   9.000000e-04
# 3   0.748438  0.602730       0.26625  5.962537   9.000000e-04
# 4   0.765625  0.566133       0.49125  2.792930   9.000000e-04
# 5   0.789062  0.523556       0.34875  5.389711   1.800000e-04
# 6   0.848125  0.389322       0.60750  1.554904   1.800000e-04
# 7   0.873438  0.333755       0.75000  0.743001   1.800000e-04
# 8   0.897969  0.280957       0.81375  0.523549   1.800000e-04
# 9   0.909375  0.257888       0.80875  0.557902   1.800000e-04
# 10  0.918750  0.229420       0.85625  0.436825   1.620000e-04
# 11  0.926875  0.211631       0.86500  0.427864   1.620000e-04
# 12  0.929219  0.205922       0.87750  0.368504   1.620000e-04
# 13  0.941562  0.179465       0.90750  0.263189   1.620000e-04
# 14  0.948594  0.159272       0.86875  0.379546   1.620000e-04
# 15  0.949844  0.158827       0.84750  0.466175   1.620000e-04
# 16  0.950781  0.147214       0.83750  0.462666   1.620000e-04
# 17  0.953125  0.142144       0.86000  0.388471   1.620000e-04
# 18  0.963437  0.121095       0.92250  0.221336   1.620000e-04
# 19  0.963125  0.116933       0.87500  0.331600   1.620000e-04
# 20  0.963906  0.119202       0.89375  0.319130   1.458000e-04
# 21  0.972656  0.095770       0.90875  0.284884   1.458000e-04
# 22  0.971719  0.092782       0.93875  0.191312   1.458000e-04
# 23  0.974219  0.085680       0.91125  0.257448   1.458000e-04
# 24  0.973906  0.086162       0.94500  0.210390   1.458000e-04
# 25  0.974063  0.084101       0.91750  0.262976   1.458000e-04
# 26  0.976875  0.078026       0.86000  0.471370   1.458000e-04
# 27  0.979219  0.075282       0.92000  0.299520   2.916000e-05
# 28  0.986562  0.050872       0.94750  0.184329   2.916000e-05
# 29  0.989844  0.038333       0.95125  0.146315   2.916000e-05
# 30  0.990781  0.037300       0.96000  0.132973   2.624400e-05
# 31  0.993594  0.032633       0.96125  0.118325   2.624400e-05
# 32  0.992344  0.031353       0.96250  0.112108   2.624400e-05
# 33  0.992813  0.030994       0.96125  0.115956   2.624400e-05
# 34  0.993906  0.028782       0.96375  0.100511   2.624400e-05
# 35  0.993750  0.031475       0.96625  0.101175   2.624400e-05
# 36  0.994062  0.027979       0.96500  0.109799   2.624400e-05
# 37  0.993750  0.029734       0.96625  0.100501   2.624400e-05
# 38  0.995313  0.023910       0.96750  0.096889   2.624400e-05
# 39  0.992656  0.028985       0.96750  0.093721   2.624400e-05
# 40  0.995313  0.024224       0.96250  0.131310   2.361960e-05
# 41  0.996094  0.020480       0.96875  0.106912   2.361960e-05
# 42  0.996094  0.024141       0.97250  0.096666   2.361960e-05
# 43  0.996719  0.018741       0.96750  0.104029   2.361960e-05
# 44  0.996094  0.019338       0.97375  0.097780   4.723920e-06
# 45  0.997187  0.020881       0.97500  0.095295   4.723920e-06
# 46  0.997500  0.016552       0.97625  0.086021   4.723920e-06
# 47  0.996250  0.018919       0.97500  0.076934   4.723920e-06
# 48  0.996719  0.016823       0.97500  0.083276   4.723920e-06
# 49  0.997187  0.018652       0.97500  0.082739   4.723920e-06
# 50  0.997813  0.015443       0.97125  0.082127   4.251528e-06
# 51  0.997187  0.018311       0.97500  0.088656   4.251528e-06
# 52  0.997813  0.016505       0.97250  0.082260   1.000000e-06
# 53  0.998281  0.013971       0.97250  0.082000   1.000000e-06
# 54  0.997187  0.016847       0.97250  0.082134   1.000000e-06
# 55  0.997813  0.016260       0.97375  0.080924   1.000000e-06
# 56  0.997187  0.016092       0.97250  0.081316   1.000000e-06
# 57  0.997969  0.016479       0.97375  0.080872   1.000000e-06

# %%
# Plot training history
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# %%
import os
import shutil
import zipfile

# Define the directory containing the files
source_directory = '/kaggle/working/'

# List of file extensions to include
file_extensions = ['.png', '.csv', '.txt','.keras']

# Create a new directory for the selected files
selected_directory = '/kaggle/working/SelectedFiles/'
os.makedirs(selected_directory, exist_ok=True)

# Move the selected files into the new directory
for foldername, subfolders, filenames in os.walk(source_directory):
    for filename in filenames:
        if any(filename.endswith(ext) for ext in file_extensions):
            source_path = os.path.join(foldername, filename)
            destination_path = os.path.join(selected_directory, filename)
            shutil.move(source_path, destination_path)

# Create a ZipFile object
zip_filename = f"{model_name}.zip"
with zipfile.ZipFile(zip_filename, 'w') as zipf:
    # Add the selected directory and its contents to the zip file
    for foldername, _, filenames in os.walk(selected_directory):
        for filename in filenames:
            file_path = os.path.join(foldername, filename)
            zipf.write(file_path, os.path.relpath(file_path, selected_directory))

print(f'{zip_filename} created successfully.')
# Out:
# MobileNetV2.zip created successfully.
